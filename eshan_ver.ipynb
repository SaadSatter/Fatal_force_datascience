# %%
import itertools

import numpy
import pandas as pd
import random
import sklearn
from sklearn.model_selection import train_test_split
import datetime
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb

# %%
"""
Our first goal is going to be data cleaning and munging. We want to take care of all null values
first.
"""

df_training = pd.read_csv('police_killings_train.csv')
df_test = pd.read_csv('police_killings_test.csv')
df_race_city = pd.read_csv('share_race_by_city.csv')
df_income = pd.read_csv('income.csv', encoding="ANSI")
df_poverty = pd.read_csv('poverty.csv', encoding="ANSI")
df_education = pd.read_csv('education.csv', encoding="ANSI")

df_test.info()
df_training
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       507 non-null    int64
#  1   name                     507 non-null    object
#  2   date                     507 non-null    object
#  3   manner_of_death          507 non-null    object
#  4   armed                    504 non-null    object
#  5   age                      467 non-null    float64
#  6   gender                   507 non-null    object
#  7   race                     403 non-null    object
#  8   city                     507 non-null    object
#  9   state                    507 non-null    object
#  10  signs_of_mental_illness  507 non-null    bool
#  11  threat_level             507 non-null    object
#  12  flee                     469 non-null    object
#  13  body_camera              507 non-null    bool
# dtypes: bool(2), float64(1), int64(1), object(10)
# memory usage: 48.6+ KB
#         id                   name      date   manner_of_death       armed  \
# 0        3             Tim Elliot  02/01/15              shot         gun
# 1        4       Lewis Lee Lembke  02/01/15              shot         gun
# 2        5     John Paul Quintero  03/01/15  shot and Tasered     unarmed
# 3        8        Matthew Hoffman  04/01/15              shot  toy weapon
# 4        9      Michael Rodriguez  04/01/15              shot    nail gun
# ...    ...                    ...       ...               ...         ...
# 2023  2256   Jeremy Lopez-Robledo  24/01/17              shot       knife
# 2024  2257    Jonathan David Sper  24/01/17              shot     unarmed
# 2025  2258  Jose Efrain Rodriguez  24/01/17  shot and Tasered         gun
# 2026  2259          Ramon Milanez  24/01/17              shot         gun
# 2027  2260       Micah R. Lambert  25/01/17              shot     vehicle
#
#        age gender race             city state  signs_of_mental_illness  \
# 0     53.0      M    A          Shelton    WA                     True
# 1     47.0      M    W            Aloha    OR                    False
# 2     23.0      M    H          Wichita    KS                    False
# 3     32.0      M    W    San Francisco    CA                     True
# 4     39.0      M    H            Evans    CO                    False
# ...    ...    ...  ...              ...   ...                      ...
# 2023  29.0      M    H       Las Cruces    NM                     True
# 2024  30.0      M    W  Algoma Township    MI                     True
# 2025  18.0      M    H   Lancaster City    PA                    False
# 2026  32.0      M    H             Kuna    ID                    False
# 2027  37.0      M    W           Oxford    AL                     True
#
#      threat_level         flee  body_camera
# 0          attack  Not fleeing        False
# 1          attack  Not fleeing        False
# 2           other  Not fleeing        False
# 3          attack  Not fleeing        False
# 4          attack  Not fleeing        False
# ...           ...          ...          ...
# 2023       attack         Foot         True
# 2024       attack  Not fleeing        False
# 2025       attack  Not fleeing        False
# 2026       attack          Car        False
# 2027       attack          Car        False
#
# [2028 rows x 14 columns]

# %%
"""
We will combine the training and tesing dataset to make cleaning easier and more accurate
"""

df_total = df_training.append(df_test, ignore_index=True)
df_total
# Out:
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2679408363.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_total = df_training.append(df_test, ignore_index=True)
#         id                name      date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  02/01/15              shot         gun  53.0
# 1        4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2        5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4        9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
# ...    ...                 ...       ...               ...         ...   ...
# 2530  2822    Rodney E. Jacobs  28/07/17              shot         gun  31.0
# 2531  2813               TK TK  28/07/17              shot     vehicle   NaN
# 2532  2818  Dennis W. Robinson  29/07/17              shot         gun  48.0
# 2533  2817       Isaiah Tucker  31/07/17              shot     vehicle  28.0
# 2534  2815        Dwayne Jeune  31/07/17              shot       knife  32.0
#
#      gender race           city state  signs_of_mental_illness threat_level  \
# 0         M    A        Shelton    WA                     True       attack
# 1         M    W          Aloha    OR                    False       attack
# 2         M    H        Wichita    KS                    False        other
# 3         M    W  San Francisco    CA                     True       attack
# 4         M    H          Evans    CO                    False       attack
# ...     ...  ...            ...   ...                      ...          ...
# 2530      M  NaN    Kansas City    MO                    False       attack
# 2531      M  NaN    Albuquerque    NM                    False       attack
# 2532      M  NaN          Melba    ID                    False       attack
# 2533      M    B        Oshkosh    WI                    False       attack
# 2534      M    B       Brooklyn    NY                     True       attack
#
#              flee  body_camera
# 0     Not fleeing        False
# 1     Not fleeing        False
# 2     Not fleeing        False
# 3     Not fleeing        False
# 4     Not fleeing        False
# ...           ...          ...
# 2530  Not fleeing        False
# 2531          Car        False
# 2532          Car        False
# 2533          Car         True
# 2534  Not fleeing        False
#
# [2535 rows x 14 columns]

# %%
print(df_income.info())
df_race_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29322 entries, 0 to 29321
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  29322 non-null  object
#  1   City             29322 non-null  object
#  2   Median Income    29271 non-null  object
# dtypes: object(3)
# memory usage: 687.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29268 entries, 0 to 29267
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Geographic area        29268 non-null  object
#  1   City                   29268 non-null  object
#  2   share_white            29268 non-null  object
#  3   share_black            29268 non-null  object
#  4   share_native_american  29268 non-null  object
#  5   share_asian            29268 non-null  object
#  6   share_hispanic         29268 non-null  object
# dtypes: object(7)
# memory usage: 1.6+ MB

# %%
"""
There are many missing fields across all the supporting/optional datasets, in order to resolve this we need
to merge these datasets and then make the necessary imputation.
1. All data sets have a state and city type columns, merge those columns such that they can all have a column
to for indexing.
2. Get the list of cities within the mandatory dataset, we need to confirm that the supporting dataset
has these cities and if not then we need to impute.
"""
#make a list of unique cities, and include the state so we don't deal with same city names of different states
df_total['city'] = df_total[['state', 'city']].apply("-".join,axis=1)
df_race_city['city'] = df_race_city[['Geographic area', 'City']].apply("-".join,axis=1)
df_income['city'] = df_income[['Geographic Area', 'City']].apply("-".join,axis=1)
df_poverty['city'] = df_poverty[['Geographic Area', 'City']].apply("-".join,axis=1)
df_education['city'] = df_education[['Geographic Area', 'City']].apply("-".join,axis=1)
df_income = df_income.drop(['Geographic Area', 'City'], axis=1)
df_poverty = df_poverty.drop(columns=['Geographic Area', 'City'])
df_education = df_education.drop(columns=['Geographic Area', 'City'])
cities = df_total['city'].tolist()
cities =list(set(cities))
print(len(cities))
cities
# Out:
# 1534
# ['MO-Harrisonville',
#  'CT-Mashantucket',
#  'CA-Sylmar',
#  'OK-Miami',
#  'ME-Orrington',
#  'AZ-Bisbee',
#  'GA-Bonaire',
#  'GA-Riverdale',
#  'CA-Chino',
#  'GA-Peachtree City',
#  'TX-Hutchins',
#  'FL-Noma',
#  'CA-Saratoga',
#  'NY-Islip',
#  'FL-Manatee',
#  'KY-Leitchfield',
#  'WY-Laramie',
#  'WI-Pine River',
#  'OH-St. Clair Township',
#  'CT-Fairfield',
#  'OH-Mansfield',
#  'NV-Boulder City',
#  'MS-Gulfport',
#  'WA-Ridgefield',
#  'WI-East Troy',
#  'OH-Brookville',
#  'FL-Cantonment',
#  'MS-Water Valley',
#  'SC-Johnsonville',
#  'FL-Englewood',
#  'KY-Ludlow',
#  'WA-Beaver',
#  'TX-Fuqua',
#  'IA-Urbandale',
#  'CO-Broomfield',
#  'WV-Princeton',
#  'AR-Desha',
#  'LA-Mandeville',
#  'CA-Watsonville',
#  'CA-Santa Clara',
#  'MO-Sullivan',
#  'LA-Denham Springs',
#  'WA-Wapato',
#  'IA-Wellman',
#  'CA-Elk Grove',
#  'LA-Franklin',
#  'UT-Eagle Mountain',
#  'TN-Monteagle',
#  'TX-Wood County',
#  'WI-Appleton',
#  'FL-Deland',
#  'MD-Greenbelt',
#  'SC-Iva',
#  'TN-Jackson',
#  'MO-Columbia',
#  'TN-Gray',
#  'CA-City Terrace',
#  'PA-Allentown',
#  'MS-Greenville',
#  'FL-Gainesville',
#  'MD-District Heights',
#  'VT-Burlington',
#  'PA-Upper Darby',
#  'ME-Waldoboro',
#  'KY-Barbourville',
#  'AR-Sheridan',
#  'IL-Antioch',
#  'TN-Lewisburg',
#  'FL-Bradenton',
#  'AL-Jackson County',
#  'MO-Neosho',
#  'OK-Kiowa',
#  'FL-Weeki Wachi',
#  'CA-Madera',
#  'OK-Muskogee',
#  'AZ-Wilhoit',
#  'PA-Johnstown',
#  'MN-Alexandria',
#  'MN-New Hope',
#  'MD-Elkton',
#  'CA-Concord',
#  'VA-King George',
#  'CO-Mountain View',
#  'MD-Woodlawn',
#  'TN-Mt. Pleasant',
#  'FL-Crescent City',
#  'TN-Dickson',
#  'FL-Middleburg',
#  'OH-Toledo',
#  'SC-Lake View',
#  'GA-Elberton',
#  'UT-Milcreek',
#  'TN-Nashville',
#  'CA-Santa Clarita',
#  'OH-Vandalia',
#  'TX-Arlington',
#  'PA-Stewartstown',
#  'FL-Hallandale Beach',
#  'TX-Springtown',
#  'TX-Garland',
#  'CA-Watsonsville',
#  'MO-Sugar Creek',
#  'IN-Evansville',
#  'TX-Austin',
#  'CA-Long Beach',
#  'SC-Pelzer',
#  'IL-Rantoul',
#  'VA-Alexandria',
#  'KY-Brodhead',
#  'TX-Fulshear',
#  'KY-Berea',
#  'WV-Morgantown',
#  'CA-South El Monte',
#  'AL-Washington County',
#  'NM-Artesia',
#  'TX-Tahoka',
#  'CT-Suffield',
#  'NY-Berne',
#  'PA-Lewistown',
#  'PA-Huntingdon County',
#  'TX-Boerne',
#  'OK-Okmulgee County',
#  'GA-Rockville',
#  'WI-Beaver Dam',
#  'AR-Mountain Pine',
#  'CA-Atascadero',
#  'VA-Harrisonburg',
#  'MI-Portage',
#  'AL-Lawrence County',
#  'SC-Chesterfield County',
#  'NV-Jean',
#  'AL-Monroeville',
#  'OH-Circleville',
#  'IL-Harvey',
#  'TN-Columbia',
#  'AK-Kenai Peninsula',
#  'CA-Seaside',
#  'TX-Brownsville',
#  'CA-La Mirada',
#  'CA-Pinion Hills',
#  'CA-San Ysidro',
#  'HI-Honolulu',
#  'CT-Bridgeport',
#  'TX-Fritch',
#  'TX-Weatherford',
#  'FL-Plant City',
#  'WI-Rib Mountain',
#  'MN-Peterson',
#  'TX-Henderson County',
#  'FL-Oakland Park',
#  'MO-St Louis',
#  'WA-Olympia',
#  'TX-Mabank',
#  'WV-Follansbee',
#  'TN-Whitehaven',
#  'OR-McMinnville',
#  'NJ-Paterson',
#  'CA-Merced',
#  'CA-Corning',
#  'IN-French Lick',
#  'IA-Boone',
#  'CA-Santa Monica',
#  'AR-Farmington',
#  'CA-San Francisco',
#  'SC-Lexington',
#  'WA-Woodland',
#  'TN-Sparta',
#  'FL-Floral City',
#  'CA-East Hollywood',
#  'OH-Madison Township',
#  'CA-Santa Ana',
#  'MS-St. Martin',
#  'KY-Simpsonsville',
#  'MN-Aitkin',
#  'IL-Benton',
#  'NY-Yonkers',
#  'NC-Cary',
#  'MI-Detroit',
#  'MO-Independence',
#  'AR-Austin',
#  'AZ-Avondale',
#  'TN-Clarksville',
#  'FL-Jupiter',
#  'UT-Provo',
#  'CA-Riverside',
#  'PA-Straban Township',
#  'NC-Newton Grove',
#  'GA-Commerce',
#  'NC-Anson County',
#  'LA-Homer',
#  'AZ-Bullhead City',
#  'TX-Ellis County',
#  'CA-Chico',
#  'GA-Cochran',
#  'VA-Grayson County',
#  'WA-Fife',
#  'CA-Redding',
#  'MO-McDowell',
#  'KY-Paris',
#  'SC-Irmo',
#  'PA-Lower Mount Bethel',
#  'MS-Petal',
#  'NY-Queens',
#  'NJ-Winslow',
#  'CA-South Los Angeles',
#  'OH-Hudson',
#  'MS-Smithville',
#  'LA-Pride',
#  'CA-Avenal',
#  'TX-Friendswood',
#  'CO-New Castle',
#  'CA-Grass Valley',
#  'OK-McAlester',
#  'TX-Nacogdoches',
#  'CA-Jurupa Valley',
#  'IN-Terre Haute',
#  'CA-Studio City',
#  'MA-Oxford',
#  'NE-York',
#  'NE-Louisville',
#  'NV-Silver Springs',
#  'OH-Willoughby',
#  'TX-Rosser',
#  'GA-Cartersville',
#  'WA-Auburn',
#  'AR-Mena',
#  'CA-Smartsville',
#  'FL-Lakeland',
#  'CA-Byron',
#  'TX-San Angelo',
#  'NJ-Cranbury Township',
#  'NC-Lenoir',
#  'AL-Phenix City',
#  'NM-Hanover',
#  'CO-Denver',
#  'FL-Palm Beach Gardens',
#  'PA-Sharon',
#  'NC-Union Grove',
#  'NM-Hobbs',
#  'VA-Falls Church',
#  'CA-Hayward',
#  'MS-Lucedale',
#  'CA-Pico Rivera',
#  'HI-Keaau',
#  'WI-Oshkosh',
#  'GA-Sylvester',
#  'PA-Campbelltown',
#  'MI-Bay City',
#  'OH-Howland Township',
#  'TN-Morristown',
#  'TX-Irving',
#  'TN-Oneida',
#  'VA-Pulaski',
#  'SC-Aiken',
#  'CA-Ceres',
#  'CA-West Goshen',
#  'KS-McPherson',
#  'OH-Mt. Auburn',
#  'CA-Sand City',
#  'OR-Wilderville',
#  'CO-Ca\x96on City',
#  'AZ-Chandler',
#  'ME-Arundel',
#  'NY-Coney Island',
#  'MN-Plymouth',
#  'FL-Miami Gardens',
#  'FL-Lakes Wales',
#  'MN-Morris',
#  'MN-Hutchinson',
#  'IN-Fort Wayne',
#  'KY-Fulton',
#  'AR-Dover',
#  'CA-Clovis',
#  'TX-Port Arthur',
#  'CO-Aurora',
#  'TX-Cisco',
#  'GA-Lizella',
#  'WA-Kelso',
#  'NC-Statesville',
#  'MO-Jackson',
#  'NH-Peterborough',
#  'MI-Manistee',
#  'MI-Wyoming',
#  'WV-Nitro',
#  'MD-Fort Meade',
#  'NM-Los Lunas',
#  'OR-Medford',
#  'IL-Villa Park',
#  'FL-Panama City',
#  'CA-Hesperia',
#  'GA-Clarkesville',
#  'OR-Tualatin',
#  'SD-Rapid City',
#  'TN-Spring Hill',
#  'AK-Barrow',
#  'FL-Tampa',
#  'NY-New York',
#  'OK-Colbert',
#  'AL-Clay',
#  'CA-McKinneyville',
#  'CA-Fountain Valley',
#  'CA-Santa Cruz',
#  'KS-Udall',
#  'NH-Claremont',
#  'LA-Harvey',
#  'SC-Lake City',
#  'IN-Hanover',
#  'NC-East Flat Rock',
#  'GA-Stone Mountain',
#  'CA-Poway',
#  'LA-Port Barre',
#  'OH-Findlay',
#  'NC-Clinton',
#  'MS-Ruth',
#  'CA-San Fernando',
#  'IA-Burlington',
#  'TX-Odessa',
#  'AR-Benton',
#  'GA-Mableton',
#  'AK-Houston',
#  'CA-Sacramento',
#  'TN-Gallatin',
#  'MI-St. Joseph',
#  'CA-Panorama City',
#  'KY-Daviess County',
#  'OH-Northwood',
#  'NJ-Brick Township',
#  'LA-Slidell',
#  'CA-Calimesa',
#  'IL-Maeystown',
#  'CA-Camarillo',
#  'AZ-Pima',
#  'NC-Franklin',
#  'KS-Assaria',
#  'AZ-Gilbert',
#  'WI-Jackson',
#  'MO-Buffalo',
#  'IL-Jerseyville',
#  'NM-Albuquerque',
#  'WA-Kirkland',
#  'CA-Newport Beach',
#  'MA-Braintree',
#  'TX-Amarillo',
#  'CO-Loveland',
#  'NC-Gaston County',
#  'CA-Fresno',
#  'CA-San Jose',
#  'GA-Ludowici',
#  'AR-Fayetteville',
#  'FL-Yulee',
#  'TX-Jourdanton',
#  'NC-Pleasant Hill',
#  'MD-Mt Airy',
#  'PA-Chambersburg',
#  'OH-Beverly',
#  'WV-Petroleum',
#  'AZ-Winslow',
#  'OH-North Royalton',
#  'UT-West Jordan',
#  'FL-Deltona',
#  'FL-Holiday',
#  'MI-Algoma Township',
#  'MS-Iuka',
#  'CA-Coalinga',
#  'GA-Valdosta',
#  'ID-Boise',
#  'GA-Gainesville',
#  'LA-Plaquemine',
#  'GA-Rossville',
#  'IA-Cedar Rapids',
#  'MA-Weymouth',
#  'MN-Roseville',
#  'CA-Torrance',
#  'LA-Converse',
#  'MA-Everett',
#  'FL-Titusville',
#  'CA-San Mateo',
#  'WI-Lake Hallie',
#  'TN-Decatur County',
#  'OR-Portland',
#  'FL-Opa-Locka',
#  'FL-Melbourne',
#  'SD-Lead',
#  'TX-Ponder',
#  'NJ-Bridgeton',
#  'OR-West Linn',
#  'KY-Gunlock',
#  'MD-Columbia',
#  'NV-North Las Vegas',
#  'OH-Canton',
#  'CA-Brawley',
#  'CO-Grand Junction',
#  'VA-Arlington',
#  'OH-Perry Township',
#  'CO-Parker',
#  'RI-Tiverton',
#  'ID-Middleton',
#  'OK-Ponca City',
#  'AL-Tuscaloosa',
#  'CA-Cabazon',
#  'AR-Bull Shoals',
#  'LA-Mamou',
#  'MI-Marion',
#  'TX-Mission',
#  'OH-Oak Hill',
#  'CA-Atwater',
#  'MD-Dundalk',
#  'FL-Homestead',
#  'GA-White',
#  'GA-Austell',
#  'CA-Solvang',
#  'OK-Rufe',
#  'TX-Gilmer',
#  'CO-Centennial',
#  'CA-Alhambra',
#  'NM-Ruidoso',
#  'WA-Des Moines',
#  'CA-Boyle Heights',
#  'DE-Middletown',
#  'SC-Taylors',
#  'KY-Phelps',
#  'SC-Boiling Springs',
#  'AL-Tuscumbia',
#  'LA-Alexandria',
#  'CA-Rocklin',
#  'TX-Harker Heights',
#  'GA-Brooklet',
#  'MT-Huntley',
#  'OK-Cache',
#  'WA-Everett',
#  'CA-Meadow Vista',
#  'NC-Iredell County',
#  'KY-Morehead',
#  'SC-Little Mountain',
#  'CA-Cerritos',
#  'MN-North Branch',
#  'AK-Spenard',
#  'FL-Ft. Lauderdale',
#  'NM-San Rafael',
#  'AK-Fairbanks',
#  'GA-Loganville',
#  'OK-Tulsa',
#  'TN-Humboldt',
#  'TN-Soddy-Daisy',
#  'WI-Geneva',
#  'AL-Homewood',
#  'WI-Corning',
#  'FL-Lake Wales',
#  'WA-Bainbridge Island',
#  'TN-McLemoresville',
#  'WI-Ashwaubenon',
#  'MO-Odessa',
#  'IL-Rockford',
#  'CA-Cottonwood',
#  'OH-Montpelier',
#  'TX-Fort Worth',
#  'NM-Rowe',
#  'OR-Bend',
#  'UT-Roosevelt',
#  'CA-Porterville',
#  'VA-Norman',
#  'AR-Cabot',
#  'CA-Palmdale',
#  'HI-Papaaloa',
#  'NJ-Lyndhurst',
#  'LA-New Orleans',
#  'NJ-Little Egg Harbor Township',
#  'IN-Shelbyville',
#  'MD-Frederick',
#  'CA-San Diego County',
#  'FL-Jacksonville',
#  'NM-Santa Fe',
#  'IN-Knox',
#  'GA-Acworth',
#  'OH-Celina',
#  'CA-Bellflower',
#  'SD-Rosebud',
#  'TN-Arlington',
#  'AL-Huntsville',
#  'NC-Asheville',
#  'OH-Uniontown',
#  'WA-Lakewood',
#  'NM-Laguna Pueblo',
#  'TX-Midland',
#  'FL-Port St. Lucie',
#  'NE-Lincoln',
#  'MO-St. Louis',
#  'AZ-Somerton',
#  'AR-Manila',
#  'FL-Plantation',
#  'CA-Rosemead',
#  'GA-Stockbridge',
#  'VA-Emporia',
#  'WI-Millston',
#  'MO-Ozark',
#  'TX-Lorena',
#  'MO-Jennings',
#  'OK-Leedey',
#  'TN-Bristol',
#  'TX-Euless',
#  'OK-Lawton',
#  'IL-Shawnee National Forest',
#  'OK-Fairland',
#  'ND-Bismarck',
#  'GA-Macon',
#  'VA-Stafford',
#  'WI-Pembine',
#  'NJ-Hackensack',
#  'NC-Fayetteville',
#  'KS-Hutchinson',
#  'ME-Portland',
#  'VA-Scott County',
#  'WI-Fond du Lac',
#  'CO-Englewood',
#  'ME-Bangor',
#  'TX-Oak Cliff',
#  'OR-Wolf Creek',
#  'KY-Bardstown',
#  'NY-Malone',
#  'WA-Wenatchee',
#  'WI-Greenfield',
#  'OK-Fairfax',
#  'CO-Federal Heights',
#  'CA-Irvine',
#  'IL-Dolton',
#  'FL-Brooksville',
#  'CA-Twentynine Palms',
#  'NY-Rotterdam',
#  'FL-Auburndale',
#  'GA-Carrollton',
#  'FL-Tallahassee',
#  'IN-Goshen',
#  'OH-Cleveland',
#  'MD-Capitol Heights',
#  'MO-Affton',
#  'TX-Laredo',
#  'MN-St. Cloud',
#  'CA-Lancaster',
#  'FL-Riverview',
#  'AL-Dadeville',
#  'IL-Round Lake',
#  'LA-East Baton Rouge',
#  'NY-Constantia',
#  'KY-Georgetown',
#  'KY-Elizabethtown',
#  'FL-Gifford',
#  'NC-Kinston',
#  'TX-Splendora',
#  'TX-Gladewater',
#  'VT-Winooski',
#  'WI-Weston',
#  'OH-Columbus',
#  'NC-Durham',
#  'GA-Jesup',
#  'FL-Miami',
#  'WA-Lynnwood',
#  'OK-Norwood',
#  'FL-Little Havana',
#  'MS-Tupelo',
#  'IL-Joilet',
#  'LA-Ragley',
#  'IN-Harmony',
#  'TX-North Laredo',
#  'FL-Lake Asbury',
#  'WV-Spencer',
#  'WV-Augusta',
#  'NC-Gastonia',
#  'AL-Mobile',
#  'TN-Gibson County',
#  'MI-Lansing',
#  'TX-Balch Springs',
#  'NY-New City',
#  'CA-Whittier',
#  'CA-Wasco',
#  'AZ-Cottonwood',
#  'NV-Gardnerville Ranchos',
#  'PA-Reading',
#  'CA-Aguanga',
#  'OH-Westlake',
#  'TX-Beckville',
#  'OK-Pryor',
#  'OH-Twinsburg',
#  'CA-Douglas City',
#  'AZ-Glendale',
#  'FL-Panama City Beach',
#  'GA-Augusta',
#  'CA-Chatsworth',
#  'IL-Lawndale',
#  'WY-Cheyenne',
#  'WA-Pasco',
#  'NJ-New Brunswick',
#  'CA-Hacienda Heights',
#  'CA-Santee',
#  'WV-Mount Hope',
#  'MS-Brookhaven',
#  'GA-Fort Valley',
#  'VA-Virginia Beach',
#  'CA-Norwalk',
#  'LA-Chalmette',
#  'AL-Bay Minette',
#  'AZ-Kearny',
#  'NV-Carson City',
#  'UT-Clearfield',
#  'PA-Union Township',
#  'WI-Wausau',
#  'CO-Thornton',
#  'SC-Cayce',
#  'CA-Tustin',
#  'CA-Huntington Beach',
#  'TX-Spring',
#  'TN-Antioch',
#  'AZ-Lake Havasu City',
#  'SC-Spartanburg',
#  'MD-Elkridge',
#  'AL-Clanton',
#  'GA-Arlington',
#  'WA-Lacey',
#  'OK-Stillwater',
#  'CA-Selma',
#  'CA-Point Loma',
#  'WA-Muckleshoot Indian Reservation',
#  'DE-Wilmington',
#  'LA-Pineville',
#  'WV-Hometown',
#  'ID-Kuna',
#  'NJ-Old Bridge',
#  'LA-Winnsboro',
#  'GA-Woodstock',
#  'KY-Owensboro',
#  'FL-Fort Lauderdale',
#  'AK-Wasilla',
#  'MI-Trenton',
#  'PA-Somerset',
#  'MO-Springfield',
#  'OR-Colton',
#  'NM-Gallup',
#  'MN-St. Paul',
#  'CT-Thomaston',
#  'TX-Levelland',
#  'MN-Vadnais Heights',
#  'CA-Castaic',
#  'CA-Chowchilla',
#  "MO-Lee's Summit",
#  'CA-Orange',
#  'AL-Rainbow City',
#  'OR-Oregon City',
#  'NC-Ronda',
#  'WY-Gillette',
#  'WA-Sumas',
#  'OH-Medina',
#  'CA-Modesto',
#  'MA-Taunton',
#  'TX-West Odessa',
#  'OK-Okemah',
#  'IL-North Riverside',
#  'MI-Eaton Rapids Township',
#  'CA-Turlock',
#  'TX-Abilene',
#  'MI-Belleville',
#  'OH-Kent',
#  'MN-Bloomington',
#  'WA-Tacoma',
#  'CA-Oxnard',
#  'CA-Hawaiian Gardens',
#  'NC-Shelby',
#  'ME-Smyrna',
#  'IN-Vincennes',
#  'KY-Pine Top',
#  'GA-Decatur',
#  'KY-Chavies',
#  'CO-Westminster',
#  'CA-University City',
#  'PA-Knoxville',
#  'LA-Shreveport',
#  'TN-West Knox',
#  'GA-Cedartown',
#  'AL-Millbrook',
#  'TN-Chattanooga',
#  'NM-Lovington',
#  'CA-Escondido',
#  'TX-Mesquite',
#  'WV-Brandywine',
#  'TN-Hendersonville',
#  'NJ-Hamilton',
#  'AL-Killeen',
#  'MD-Owings Mills',
#  'CA-South Gate',
#  'AL-Eastaboga',
#  'MO-Poplar Bluff',
#  'PA-Pittston',
#  'AZ-Sierra Vista',
#  'CA-Maywood',
#  'CA-Ontario',
#  'FL-Orange Park',
#  'CA-Tehachapi',
#  'FL-Thonotosassa',
#  'HI-Aiea',
#  'CA-El Cajon',
#  'AR-Perryville',
#  'TN-Estill Springs',
#  'CA-Yorba Linda',
#  'ME-Naples',
#  'MN-Vineland',
#  'CA-Fairfield',
#  'NM-Pueblo of Laguna',
#  'OH-Parma',
#  'OK-Schulter',
#  'TX-San Antonio',
#  'AR-Springdale',
#  'NC-Raleigh',
#  'GA-Lumpkin',
#  'VA-Pearisburg',
#  'AL-Deer Park',
#  'CA-Glendale',
#  'ID-Homedale',
#  'TN-Elizabethton',
#  'FL-Hog Valley',
#  'NC-Ashe County',
#  'IL-Hurst',
#  'CA-Venice',
#  'KS-Colby',
#  'GA-Lawrenceville',
#  'MA-Webster',
#  'AL-Baldwin County',
#  'MD-Essex',
#  'WI-Sheboygan',
#  'KS-Wichita',
#  'IL-Zion',
#  'FL-North Port',
#  'FL-Cape Coral',
#  'OR-Springfield',
#  'CA-Santa Paula',
#  'AR-Jonesboro',
#  'NC-Wake Forest',
#  'IN-Indianapolis',
#  'TX-Clute',
#  'OH-Ashtabula',
#  'KS-Kansas City',
#  'ND-Wood Lake',
#  'WV-Clendenin',
#  'MA-Roslindale',
#  'NY-Troy',
#  'MN-Columbia Heights',
#  'CO-Fort Collins',
#  'UT-Syracuse',
#  'OH-Green',
#  'MT-Three Forks',
#  'IL-Alton',
#  'AL-Meridianville',
#  'MD-Randallstown',
#  'AL-Hoover',
#  'MA-Beverly',
#  'IA-Fort Madison',
#  'IL-River Forest',
#  'TX-El Paso',
#  'CT-Oakdale',
#  'MA-Lynn',
#  'CO-Commerce City',
#  'AZ-Yuma',
#  'LA-Baton Rouge',
#  'MN-Eagan',
#  'MN-Mora',
#  'MS-Southaven',
#  'CA-Clearlake Park',
#  'CA-San Bernardino',
#  'KS-Gardner',
#  'OK-Logan County',
#  'ID-Rexburg',
#  'AZ-Buckeye',
#  'FL-Carollwood',
#  'CA-Emeryville',
#  'NH-Derry',
#  'CA-Oakland',
#  'CA-Lemoore',
#  'TX-Bexar County',
#  'SC-Sumter',
#  'CA-Walnut Creek',
#  'WA-Hunters',
#  'CA-Bakersfield',
#  'NC-Spring Lake',
#  'WA-Graham',
#  'HI-Kahuku',
#  'FL-Fruitland Park',
#  'IN-Greenwood',
#  'ID-Council',
#  'OH-Englewood',
#  'FL-Immokalee',
#  'AK-Big Lake',
#  'CA-Vacaville',
#  'AL-Sylacauga',
#  'MI-Romulus',
#  'TX-Webster',
#  'CA-Yuba City',
#  'WA-East Wenatchee',
#  'TX-Fort Stockton',
#  'TX-Brookshire',
#  'OR-Clackamas County',
#  'IN-Kokomo',
#  'GA-Covington',
#  'PA-York',
#  'AZ-Flagstaff',
#  'OK-Eufaula',
#  'CA-Chula Vista',
#  'MI-Cato Township',
#  'TX-DeSoto',
#  'MT-Dillon',
#  'LA-Metairie',
#  'TX-Whitewright',
#  'WI-Wauwatosa',
#  'CA-Grover Beach',
#  'TX-Killeen',
#  'AL-Opp',
#  'AL-Selma',
#  'NM-Crownpoint',
#  'PA-Penn Township',
#  'MI-Holland Township',
#  'FL-Putnam Hall',
#  'PA-Forks Township',
#  'AL-Ashville',
#  'MS-Barton',
#  'CA-Montebello',
#  'CO-Colorado City',
#  'VA-Portsmouth',
#  'CO-Eldorado Springs',
#  'LA-Livingston Parish',
#  'MI-Dearborn',
#  'OH-Westerville',
#  'TX-Lake Jackson',
#  'CA-Huntington Park',
#  'LA-Breaux Bridge',
#  'CA-Needles',
#  'VA-Fredericksburg',
#  'FL-Niceville',
#  'GA-Port Wentworth',
#  'MA-Lowell',
#  'CO-Lakewood',
#  'SC-Hardeeville',
#  'GA-Paulding County',
#  'CA-North Hills',
#  'CA-Newman',
#  'OH-Rome',
#  'CO-Brighton',
#  'OR-Beaverton',
#  'NM-Roswell',
#  'CA-Ripon',
#  'CA-Dinuba',
#  'TX-Nocona',
#  'IN-Elkhart',
#  'LA-Crowley',
#  'MS-Columbus',
#  'MD-Abingdon',
#  'AZ-Marana',
#  'PA-Lancaster City',
#  'UT-Logan',
#  'WA-Cle Elum',
#  'NY-Mount Vernon',
#  'PA-Wilkinsburg',
#  'FL-Clermont',
#  'NM-Jal',
#  'NC-Salemburg',
#  'UT-Ogden',
#  'LA-Evangeline Parish',
#  'CA-Van Nuys',
#  'DE-Smyrna',
#  'KS-Topeka',
#  'TX-Campbellton',
#  'NM-Edgewood',
#  'CA-Lake Elsinore',
#  'IL-Arcola',
#  'MI-Southfield',
#  'OH-Euclid',
#  'CA-Azusa',
#  'CO-Pueblo',
#  'CA-Lompoc',
#  'NC-Rutherfordton',
#  'TX-Pharr',
#  'NJ-Atlantic City',
#  'FL-Ocala',
#  'WI-Paddock Lake',
#  'GA-Newnan',
#  'WV-Gerrardstown',
#  'TX-Panhandle',
#  'CA-Antelope',
#  'TN-Knoxville',
#  'GA-East Point',
#  'AZ-Scottsdale',
#  'CA-Citrus Heights',
#  'GA-Savannah',
#  'FL-Orange City',
#  'TX-Houston',
#  'FL-DeLand',
#  'CA-El Monte',
#  'IN-Muncie',
#  'WA-Grapeview',
#  'TX-Kerrville',
#  'PA-Philadelphia',
#  'NJ-Woodbridge',
#  'FL-Naples',
#  'OK-Burns Flat',
#  'TX-Allen',
#  'CA-Highland',
#  'NC-Maiden',
#  'MS-Gautier',
#  'NC-Rowland',
#  'NC-Efland',
#  'MO-St. Joseph',
#  'DE-Claymont',
#  'WI-Neenah',
#  'AZ-Goodyear',
#  'FL-Delray Beach',
#  'WI-New London',
#  'OR-King City',
#  'CA-South Lake Tahoe',
#  'OH-Akron',
#  'OK-Byars',
#  'CA-Barona Indian Reservation',
#  'NC-Salisbury',
#  'TX-Sunset',
#  'FL-Belle Glade',
#  'IL-Marion',
#  'KS-Olathe',
#  'PA-York County',
#  'FL-St. Augustine',
#  'AZ-Maricopa',
#  'AZ-Tempe',
#  'FL-Lealman',
#  'FL-Pompano Beach',
#  'NE-Big Springs',
#  'NM-Carrizozo',
#  'TN-Sevierville',
#  'MD-Bel Air',
#  'SD-Sioux Falls',
#  'VA-Richmond',
#  'CA-Sunnyvale',
#  'VA-Aldie',
#  'AZ-Golden Valley',
#  'AR-Marion',
#  'MO-Franklin County',
#  'PA-Pittsburgh',
#  'KS-Rosalia',
#  'SC-Piedmont',
#  'CA-Inglewood',
#  'VA-Arvonia',
#  'MA-West Springfield',
#  'AZ-Apache Junction',
#  'PA-Fort Littleton',
#  'SC-Seneca',
#  'TX-Pearland',
#  'MN-Mankato',
#  'VA-Roanoke',
#  'AZ-Surprise',
#  'MI-Saginaw',
#  'CA-Florence',
#  'TX-Groveton',
#  'CA-Pomona',
#  'IL-Springfield',
#  'TN-Somerville',
#  'MO-Cape Girardeau',
#  'LA-Bossier City',
#  'WV-Buckhannon',
#  'OH-Geneva Township',
#  'CO-Dinosaur',
#  'UT-Parowan',
#  'MA-Spencer',
#  'CT-Old Saybrook',
#  'AZ-Eagar',
#  'CA-Kings County',
#  'IL-Chicago',
#  'GA-Hampton',
#  'CA-Santa Nella',
#  'IL-Forest Park',
#  'FL-Micanopy',
#  'ME-Presque Isle',
#  'TX-Sierra Blanca',
#  'CA-Los Angeles',
#  'AL-Muscle Shoals',
#  'CA-Santa Barbara',
#  'HI-Hilo',
#  'TX-Saginaw',
#  'OH-Richmond Heights',
#  'CA-Delano',
#  'CA-Beaumont',
#  'FL-Jacksonsville',
#  'PA-Chester',
#  'PA-Canaan Township',
#  'OK-Anadarko',
#  'CA-Happy Valley',
#  'CA-Rancho Cordova',
#  'NY-Buffalo',
#  'NY-Greece',
#  'TN-Lenoir City',
#  'NC-Lawndale',
#  'NY-Beacon',
#  'GA-Moultrie',
#  'PA-South Greensburg',
#  'CA-Stockton',
#  'MD-Salisbury',
#  'KY-Booneville',
#  'LA-Houma',
#  'FL-Pensacola',
#  ...]

# %%
"""
First lets merge each of the supporting datasets into df_temp.
We noticed that the missing values aren't consistent in the supporting datasets. So we need to change all types of
missing values to NAN such that we can impute using fillna().
"""
print(df_race_city.info())
df_temp = pd.merge(df_race_city, df_income, on='city', how='outer', sort=True)
df_temp = pd.merge(df_temp, df_poverty, on='city', how='outer', sort=True)
df_temp = pd.merge(df_temp, df_education, on='city', how='outer', sort=True)
columns_supp = df_temp.columns.values.tolist()
for i in columns_supp:
    df_temp[i] = df_temp[i].replace('-', '(X)')
    df_temp[i] = df_temp[i].replace('(X)', numpy.NAN)
print(df_temp.info())
df_temp
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29268 entries, 0 to 29267
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Geographic area        29268 non-null  object
#  1   City                   29268 non-null  object
#  2   share_white            29268 non-null  object
#  3   share_black            29268 non-null  object
#  4   share_native_american  29268 non-null  object
#  5   share_asian            29268 non-null  object
#  6   share_hispanic         29268 non-null  object
#  7   city                   29268 non-null  object
# dtypes: object(8)
# memory usage: 1.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29477 entries, 0 to 29476
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Geographic area        29268 non-null  object
#  1   City                   29268 non-null  object
#  2   share_white            29248 non-null  object
#  3   share_black            29248 non-null  object
#  4   share_native_american  29248 non-null  object
#  5   share_asian            29248 non-null  object
#  6   share_hispanic         29248 non-null  object
#  7   city                   29477 non-null  object
#  8   Median Income          27418 non-null  object
#  9   poverty_rate           29128 non-null  object
#  10  percent_completed_hs   29132 non-null  object
# dtypes: object(11)
# memory usage: 2.7+ MB
# None
#       Geographic area                    City share_white share_black  \
# 0                  AK               Adak city        19.6           4
# 1                  AK             Akhiok city         8.5         1.4
# 2                  AK            Akiachak CDP         3.5         0.2
# 3                  AK              Akiak city         5.2           0
# 4                  AK             Akutan city        23.3        17.9
# ...               ...                     ...         ...         ...
# 29472              WY  Woods Landing-Jelm CDP        95.9           0
# 29473              WY            Worland city        89.9         0.3
# 29474              WY             Wright town        94.5         0.1
# 29475              WY           Y-O Ranch CDP        92.8         1.5
# 29476              WY              Yoder town        97.4           0
#
#       share_native_american share_asian share_hispanic  \
# 0                       5.5        52.5            8.9
# 1                      50.7         1.4           11.3
# 2                      95.1         0.2            0.2
# 3                      92.8           0            0.3
# 4                       5.5        43.3           20.8
# ...                     ...         ...            ...
# 29472                     0         2.1              0
# 29473                   1.3         0.6           16.6
# 29474                   1.4         0.2            6.2
# 29475                   2.6           0           11.8
# 29476                     0           0              4
#
#                             city Median Income poverty_rate  \
# 0                   AK-Adak city         78500         39.3
# 1                 AK-Akhiok city         26250         40.5
# 2                AK-Akiachak CDP         38750         26.1
# 3                  AK-Akiak city         42000         31.3
# 4                 AK-Akutan city         24750         16.1
# ...                          ...           ...          ...
# 29472  WY-Woods Landing-Jelm CDP           NaN         18.6
# 29473            WY-Worland city         41523         15.3
# 29474             WY-Wright town         77114          5.9
# 29475           WY-Y-O Ranch CDP           NaN            0
# 29476              WY-Yoder town         37500          5.4
#
#       percent_completed_hs
# 0                     93.4
# 1                     62.5
# 2                     76.7
# 3                     81.3
# 4                       73
# ...                    ...
# 29472                  100
# 29473                 85.6
# 29474                 89.2
# 29475                  100
# 29476                 79.4
#
# [29477 rows x 11 columns]

# %%
"""
Let's try cleaning the the race of city dataset now viewing the missing datapoints which are denoted at (X).
"""
# df_temp['city'] = df_temp[['Geographic area', 'City']].apply("-".join,axis=1)
# list_race_df = df_temp.values.tolist()
# j = 0
# list_bad_cities = []
# for i in list_race_df:
#     #we can see it is only null when all races are missing
#     if(i.count('(X)') > 0):
#         j+=1
#         list_bad_cities.append(i[1])
#         print(i.count('(X)') )
# print("total cities with bad points = ", j)
# Out:
# "\nLet's try cleaning the the race of city dataset now viewing the missing datapoints which are denoted at (X).\n"

# %%
"""With only 20/29260 holding a row of null values, we shall drop these cities"""
# tempDf_race = df_temp[df_race_city.share_white != '(X)'].copy()
# print(tempDf_race.info())
# df_race_city.info()
# Out:
# 'With only 20/29260 holding a row of null values, we shall drop these cities'

# %%
"""
We want to make sure all the cities that are in our mandatory dataset is accounted for in the supporting.
We shall add those cities if they aren't and impute them as nulls
"""
#we can check that all the cities in the total data set is still in the race_city dataset
cities2 = df_temp['city'].tolist()
cities2 =list(set(cities2))
j = 0
missing = 0
cities.sort()
cities2.sort()
rep_val = 0
for i in cities:
    # print(i in cities2)
    # print(i)
    # print(cities2.index(i[0::1]))
    if(i in cities2):
        j+=1
    elif(any(i in string for string in cities2)):
        if len(df_temp[df_temp['city'].str.contains(i) ]) == 1 and sum(i in string for string in cities) == 1:
            print(i)
            df_temp['city'].loc[df_temp['city'].str.contains(i)] = i
            rep_val+=1

        else:
            newDF = {}
            #print(i)
            newDF['Geographic area'] = i[0:2]
            newDF['City'] = i[3:]
            newDF['city'] = i
            ind = 0
            df_temp = df_temp.append(newDF, ignore_index=True)
            cities2 = df_temp['city'].tolist()
            cities2 =list(set(cities2))
            missing+=1

    else:
        newDF = {}
        #print(i)
        newDF['Geographic area'] = i[0:2]
        newDF['City'] = i[3:]
        newDF['city'] = i
        ind = 0
        df_temp = df_temp.append(newDF, ignore_index=True)
        cities2 = df_temp['city'].tolist()
        cities2 =list(set(cities2))
        missing+=1


print(j)
print("Replaced cities ", rep_val)
print(" Was Missing ", missing)
df_temp.drop_duplicates(subset='city', inplace=True)
df_temp.reset_index(inplace=True)
df_temp
# Out:
# AK-Anchorage
# AK-Barrow
# AK-Big Lake
# AK-Fairbanks
# AK-Houston
# AK-Wasilla
# AL-Abbeville
# AL-Arab
# AL-Ashville
# AL-Bay Minette
# AL-Birmingham
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# AL-Clanton
# AL-Dadeville
# AL-Deer Park
# AL-Eufaula
# AL-Gadsden
# AL-Homewood
# AL-Hoover
# AL-Huntsville
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# AL-Meridianville
# AL-Millbrook
# AL-Mobile
# AL-Monroeville
# AL-Montgomery
# AL-Muscle Shoals
# AL-Opelika
# AL-Opp
# AL-Oxford
# AL-Phenix City
# AL-Piedmont
# AL-Rainbow City
# AL-Saraland
# AL-Selma
# AL-Sylacauga
# AL-Tuscaloosa
# AL-Tuscumbia
# AL-Westover
# AR-Austin
# AR-Bull Shoals
# AR-Cabot
# AR-Dover
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# AR-England
# AR-Farmington
# AR-Fayetteville
# AR-Jonesboro
# AR-Little Rock
# AR-Manila
# AR-Marion
# AR-Mena
# AR-Mountain Pine
# AR-Perryville
# AR-Sheridan
# AR-Springdale
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# AR-Strong
# AR-West Memphis
# AZ-Apache Junction
# AZ-Avondale
# AZ-Bisbee
# AZ-Buckeye
# AZ-Bullhead City
# AZ-Casa Grande
# AZ-Chandler
# AZ-Eagar
# AZ-Flagstaff
# AZ-Florence
# AZ-Gilbert
# AZ-Glendale
# AZ-Golden Shores
# AZ-Golden Valley
# AZ-Kearny
# AZ-Kingman
# AZ-Lake Havasu City
# AZ-Marana
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# AZ-Morenci
# AZ-Phoenix
# AZ-San Manuel
# AZ-Scottsdale
# AZ-Show Low
# AZ-Somerton
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# AZ-Surprise
# AZ-Tempe
# AZ-Wilhoit
# AZ-Yuma
# CA-Aguanga
# CA-Anaheim
# CA-Anderson
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# CA-Antelope
# CA-Antioch
# CA-Apple Valley
# CA-Atascadero
# CA-Atwater
# CA-Avenal
# CA-Azusa
# CA-Bakersfield
# CA-Barstow
# CA-Beaumont
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# CA-Bellflower
# CA-Boulder Creek
# CA-Brawley
# CA-Byron
# CA-Cabazon
# CA-Calexico
# CA-Calimesa
# CA-Camarillo
# CA-Campo
# CA-Carmichael
# CA-Carson
# CA-Castaic
# CA-Cathedral City
# CA-Ceres
# CA-Cerritos
# CA-Chico
# CA-Chowchilla
# CA-Chula Vista
# CA-Citrus Heights
# CA-Clovis
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# CA-Coalinga
# CA-Colton
# CA-Compton
# CA-Concord
# CA-Corning
# CA-Cottonwood
# CA-Del Mar
# CA-Delano
# CA-Delhi
# CA-Desert Edge
# CA-Dinuba
# CA-Douglas City
# CA-Downey
# CA-Dunsmuir
# CA-El Cajon
# CA-El Monte
# CA-Elk Grove
# CA-Emeryville
# CA-Encinitas
# CA-Escondido
# CA-Eureka
# CA-Fair Oaks
# CA-Fairfield
# CA-Florence
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# IL-Jerseyville
# IL-Lansing
# IL-Lisle
# IL-Lyons
# IL-Maeystown
# IL-Marion
# IL-Markham
# IL-Metropolis
# IL-North Riverside
# IL-Rantoul
# IL-River Forest
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# IL-Rockford
# IL-Springfield
# IL-Stockton
# IL-Villa Park
# IL-Washington Park
# IL-Zion
# IN-Avon
# IN-Beech Grove
# IN-Brookville
# IN-Elkhart
# IN-English
# IN-Evansville
# IN-Fishers
# IN-Fort Wayne
# IN-French Lick
# IN-Gary
# IN-Goshen
# IN-Greenwood
# IN-Hanover
# IN-Harmony
# IN-Knox
# IN-Kokomo
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# IN-Lafayette
# IN-Monon
# IN-Muncie
# IN-Portage
# IN-Shelbyville
# IN-Terre Haute
# IN-Vincennes
# KS-Assaria
# KS-Colby
# KS-Gardner
# KS-Hesston
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# KS-Hutchinson
# KS-Kansas City
# KS-Leavenworth
# KS-Lehigh
# KS-McPherson
# KS-Medicine Lodge
# KS-Newton
# KS-Olathe
# KS-Rosalia
# KS-Topeka
# KS-Udall
# KS-Wichita
# KY-Barbourville
# KY-Bardstown
# KY-Berea
# KY-Booneville
# KY-Bowling Green
# KY-Brodhead
# KY-Burkesville
# KY-Edmonton
# KY-Elizabethtown
# KY-Elsmere
# KY-Fulton
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# KY-Georgetown
# KY-Hiseville
# KY-Lancaster
# KY-Lawrenceburg
# KY-Leitchfield
# KY-London
# KY-Ludlow
# KY-Morehead
# KY-Owensboro
# KY-Paris
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# KY-Phelps
# KY-Princeton
# KY-Richmond
# KY-Russellville
# KY-White Plains
# KY-Wilmore
# LA-Alexandria
# LA-Baton Rouge
# LA-Bossier City
# LA-Breaux Bridge
# LA-Cade
# LA-Chalmette
# LA-Converse
# LA-Covington
# LA-Crowley
# LA-Denham Springs
# LA-Gretna
# LA-Harvey
# LA-Homer
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# LA-Houma
# LA-Kenner
# LA-Mamou
# LA-Mandeville
# LA-Marksville
# LA-Metairie
# LA-New Iberia
# LA-New Orleans
# LA-Pineville
# LA-Plaquemine
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# LA-Port Barre
# LA-Raceland
# LA-Shreveport
# LA-Slidell
# LA-Winnsboro
# MA-Beverly
# MA-Boston
# MA-Braintree
# MA-Brockton
# MA-Everett
# MA-Lowell
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
# TX-Longview
# TX-Lorena
# TX-Lufkin
# TX-Mabank
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# TX-Mansfield
# TX-Midland
# TX-Midlothian
# TX-Nacogdoches
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# TX-Odessa
# TX-Onalaska
# TX-Palestine
# TX-Panhandle
# TX-Paris
# TX-Pearland
# TX-Pharr
# TX-Plano
# TX-Ponder
# TX-Port Arthur
# TX-Rosenberg
# TX-Rosser
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# TX-Saginaw
# TX-San Angelo
# TX-San Antonio
# TX-Seagoville
# TX-Sierra Blanca
# TX-Splendora
# TX-Springtown
# TX-Tahoka
# TX-Temple
# TX-Tomball
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# TX-Waco
# TX-Weatherford
# TX-Webster
# TX-West Odessa
# TX-Whitewright
# TX-Wichita Falls
# TX-Wink
# TX-Winnie
# UT-Centerville
# UT-Clearfield
# UT-Draper
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# UT-Eagle Mountain
# UT-Ogden
# UT-Parowan
# UT-Provo
# UT-Roosevelt
# UT-Roy
# UT-Salt Lake City
# UT-Spanish Fork
# UT-Syracuse
# UT-West Jordan
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# VA-Alexandria
# VA-Arlington
# VA-Chesapeake
# VA-Concord
# VA-Culpeper
# VA-Emporia
# VA-Falls Church
# VA-Fredericksburg
# VA-Grundy
# VA-Harrisonburg
# VA-Herndon
# VA-Hopewell
# VA-King George
# VA-Newport News
# VA-Norfolk
# VA-Pearisburg
# VA-Portsmouth
# VA-Pulaski
# VA-Richmond
# VA-Roanoke
# VA-Stafford
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# VA-Suffolk
# VA-Virginia Beach
# VA-Winchester
# VT-Burlington
# VT-Winooski
# WA-Auburn
# WA-Bainbridge Island
# WA-Bellingham
# WA-Burien
# WA-Cle Elum
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# WA-Des Moines
# WA-East Wenatchee
# WA-Everett
# WA-Federal Way
# WA-Graham
# WA-Grapeview
# WA-Kelso
# WA-Kennewick
# WA-Kent
# WA-Kirkland
# WA-Lacey
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# WA-Lake Stevens
# WA-Lakewood
# WA-Lynnwood
# WA-Olympia
# WA-Pasco
# WA-Richland
# WA-Ridgefield
# WA-Seattle
# WA-Shelton
# WA-Snohomish
# WA-Spanaway
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# WA-Sumas
# WA-Tacoma
# WA-Tukwila
# WA-Vancouver
# WA-Wapato
# WA-Wenatchee
# WA-Woodland
# WA-Yakima
# WI-Antigo
# WI-Appleton
# WI-Ashwaubenon
# WI-Beaver Dam
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# WI-East Troy
# WI-Eau Claire
# WI-Fond du Lac
# WI-Green Bay
# WI-Greenfield
# WI-Jackson
# WI-Kenosha
# WI-Lake Hallie
# WI-Madison
# WI-Millston
# WI-Milwaukee
# WI-Monroe
# WI-Neenah
# WI-New London
# WI-Oshkosh
# WI-Paddock Lake
# WI-Pembine
# WI-Pine River
# WI-Rib Mountain
# WI-Waukesha
# WI-Wauwatosa
# WI-West Allis
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# WI-Weston
# WV-Beckley
# WV-Bluefield
# WV-Brandywine
# WV-Buckhannon
# WV-Clendenin
# WV-Elkins
# WV-Fairmont
# WV-Follansbee
# WV-Fort Ashby
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
# WV-Grafton
# WV-Hometown
# WV-Meadow Bridge
# WV-Montcalm
# WV-Morgantown
# WV-Mount Hope
# WV-Nitro
# WV-Princeton
# WV-Spencer
# WV-Weirton
# WY-Cheyenne
# WY-Douglas
# WY-Gillette
# WY-Laramie
# WY-Rawlins
# 1
# Replaced cities  1189
#  Was Missing  344
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\2341017669.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_temp = df_temp.append(newDF, ignore_index=True)
#        index Geographic area            City share_white share_black  \
# 0          0              AK       Adak city        19.6           4
# 1          1              AK     Akhiok city         8.5         1.4
# 2          2              AK    Akiachak CDP         3.5         0.2
# 3          3              AK      Akiak city         5.2           0
# 4          4              AK     Akutan city        23.3        17.9
# ...      ...             ...             ...         ...         ...
# 29816  29816              WV  Braxton County         NaN         NaN
# 29817  29817              WV    Gerrardstown         NaN         NaN
# 29818  29818              WV         Hensley         NaN         NaN
# 29819  29819              WV       Petroleum         NaN         NaN
# 29820  29820              WY          Casper         NaN         NaN
#
#       share_native_american share_asian share_hispanic               city  \
# 0                       5.5        52.5            8.9       AK-Adak city
# 1                      50.7         1.4           11.3     AK-Akhiok city
# 2                      95.1         0.2            0.2    AK-Akiachak CDP
# 3                      92.8           0            0.3      AK-Akiak city
# 4                       5.5        43.3           20.8     AK-Akutan city
# ...                     ...         ...            ...                ...
# 29816                   NaN         NaN            NaN  WV-Braxton County
# 29817                   NaN         NaN            NaN    WV-Gerrardstown
# 29818                   NaN         NaN            NaN         WV-Hensley
# 29819                   NaN         NaN            NaN       WV-Petroleum
# 29820                   NaN         NaN            NaN          WY-Casper
#
#       Median Income poverty_rate percent_completed_hs
# 0             78500         39.3                 93.4
# 1             26250         40.5                 62.5
# 2             38750         26.1                 76.7
# 3             42000         31.3                 81.3
# 4             24750         16.1                   73
# ...             ...          ...                  ...
# 29816           NaN          NaN                  NaN
# 29817           NaN          NaN                  NaN
# 29818           NaN          NaN                  NaN
# 29819           NaN          NaN                  NaN
# 29820           NaN          NaN                  NaN
#
# [29821 rows x 12 columns]

# %%
cities2 = df_temp['city'].tolist()
cities2 =list(set(cities2))
j = 0
for i in cities:
    # print(i in cities2)
    # print(i)
    # print(cities2.index(i[0::1]))
    if(i in  cities2):
        j+=1
#confirming that all the cities were placed in
print(j)
# Out:
# 1534

# %%
df_temp.sort_values(by=['city'], inplace=True)
df_temp
# Out:
#        index Geographic area                    City share_white share_black  \
# 0          0              AK               Adak city        19.6           4
# 1          1              AK             Akhiok city         8.5         1.4
# 2          2              AK            Akiachak CDP         3.5         0.2
# 3          3              AK              Akiak city         5.2           0
# 4          4              AK             Akutan city        23.3        17.9
# ...      ...             ...                     ...         ...         ...
# 29472  29472              WY  Woods Landing-Jelm CDP        95.9           0
# 29473  29473              WY            Worland city        89.9         0.3
# 29474  29474              WY             Wright town        94.5         0.1
# 29475  29475              WY           Y-O Ranch CDP        92.8         1.5
# 29476  29476              WY              Yoder town        97.4           0
#
#       share_native_american share_asian share_hispanic  \
# 0                       5.5        52.5            8.9
# 1                      50.7         1.4           11.3
# 2                      95.1         0.2            0.2
# 3                      92.8           0            0.3
# 4                       5.5        43.3           20.8
# ...                     ...         ...            ...
# 29472                     0         2.1              0
# 29473                   1.3         0.6           16.6
# 29474                   1.4         0.2            6.2
# 29475                   2.6           0           11.8
# 29476                     0           0              4
#
#                             city Median Income poverty_rate  \
# 0                   AK-Adak city         78500         39.3
# 1                 AK-Akhiok city         26250         40.5
# 2                AK-Akiachak CDP         38750         26.1
# 3                  AK-Akiak city         42000         31.3
# 4                 AK-Akutan city         24750         16.1
# ...                          ...           ...          ...
# 29472  WY-Woods Landing-Jelm CDP           NaN         18.6
# 29473            WY-Worland city         41523         15.3
# 29474             WY-Wright town         77114          5.9
# 29475           WY-Y-O Ranch CDP           NaN            0
# 29476              WY-Yoder town         37500          5.4
#
#       percent_completed_hs
# 0                     93.4
# 1                     62.5
# 2                     76.7
# 3                     81.3
# 4                       73
# ...                    ...
# 29472                  100
# 29473                 85.6
# 29474                 89.2
# 29475                  100
# 29476                 79.4
#
# [29821 rows x 12 columns]

# %%
"""
We want to impute the city and our state/Geographic area such that we have a full comprehensive list of both
separately after the merge.
Then we want to get a list of race names within the df_race_city.
"""

df_temp['Geographic area'] = [i[0:2] for i in df_temp['city']]
df_temp['City'] = [i[3:] for i in df_temp['city']]
print(df_temp)
list_states = df_temp['Geographic area'].values.tolist()
list_states = list(set(list_states))
#we expect to see 51 including DC as a state
print(len(list_states))
columns_race = df_temp.columns.values.tolist()
s = 'share'
columns_race = [string for string in columns_race if(s in string)]
columns_race
# Out:
#        index Geographic area                    City share_white share_black  \
# 0          0              AK               Adak city        19.6           4
# 1          1              AK             Akhiok city         8.5         1.4
# 2          2              AK            Akiachak CDP         3.5         0.2
# 3          3              AK              Akiak city         5.2           0
# 4          4              AK             Akutan city        23.3        17.9
# ...      ...             ...                     ...         ...         ...
# 29472  29472              WY  Woods Landing-Jelm CDP        95.9           0
# 29473  29473              WY            Worland city        89.9         0.3
# 29474  29474              WY             Wright town        94.5         0.1
# 29475  29475              WY           Y-O Ranch CDP        92.8         1.5
# 29476  29476              WY              Yoder town        97.4           0
#
#       share_native_american share_asian share_hispanic  \
# 0                       5.5        52.5            8.9
# 1                      50.7         1.4           11.3
# 2                      95.1         0.2            0.2
# 3                      92.8           0            0.3
# 4                       5.5        43.3           20.8
# ...                     ...         ...            ...
# 29472                     0         2.1              0
# 29473                   1.3         0.6           16.6
# 29474                   1.4         0.2            6.2
# 29475                   2.6           0           11.8
# 29476                     0           0              4
#
#                             city Median Income poverty_rate  \
# 0                   AK-Adak city         78500         39.3
# 1                 AK-Akhiok city         26250         40.5
# 2                AK-Akiachak CDP         38750         26.1
# 3                  AK-Akiak city         42000         31.3
# 4                 AK-Akutan city         24750         16.1
# ...                          ...           ...          ...
# 29472  WY-Woods Landing-Jelm CDP           NaN         18.6
# 29473            WY-Worland city         41523         15.3
# 29474             WY-Wright town         77114          5.9
# 29475           WY-Y-O Ranch CDP           NaN            0
# 29476              WY-Yoder town         37500          5.4
#
#       percent_completed_hs
# 0                     93.4
# 1                     62.5
# 2                     76.7
# 3                     81.3
# 4                       73
# ...                    ...
# 29472                  100
# 29473                 85.6
# 29474                 89.2
# 29475                  100
# 29476                 79.4
#
# [29821 rows x 12 columns]
# 51
# ['share_white',
#  'share_black',
#  'share_native_american',
#  'share_asian',
#  'share_hispanic']

# %%
"""
Now we can impute the porportion of missing cities based on the state's porportions
"""
for state in list_states:
    j=0
    list_total_races = []
    state_df = df_temp.loc[df_temp['Geographic area'] == state]
    for i in columns_race:
        state_df[i] = state_df[i].astype(float)
        list_total_races.append(state_df[i].sum())
        print(list_total_races[j])
        j+=1
    sum_all_races = sum(list_total_races)
    porportional_share = [i/sum_all_races for i in list_total_races]
    #print(porportional_share, " sum= ", sum(porportional_share))
    j=0
    for i in columns_race:
        state_df[i] = state_df[i].fillna(porportional_share[j])
        j+=1
    df_temp.loc[df_temp['Geographic area'] == state] = state_df
print(df_temp.info())
df_temp
# Out:
# 51732.100000000006
# 895.9000000000001
# 2355.2
# 1930.8000000000002
# 6662.1
# 62377.899999999994
# 644.5
# 1256.9
# 286.1
# 3403.1
# 54936.2
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\
# 680.9
# 64.7
# 693.4
# 1201.9
# 52850.7
# 15077.300000000001
# 1321.4
# 684.5
# 4739.1
# 20161.6
# 67.0
# 573.1
# 110.69999999999999
# 2427.8
# 38109.200000000004
# 1169.0
# 80.30000000000001
# 136.8
# 362.59999999999997
# 53454.6
# 2474.8
# 10542.1
# 312.6
# 4175.5
# 72378.70000000001
# 12301.199999999999
# 419.0
# 1487.4
# 15206.8
# 105676.29999999999
# 4765.2
# 429.6
# 3233.3
# 7882.099999999999
# 48419.1
# 2321.1000000000004
# 110.30000000000001
# 373.3
# 1168.4
# 44084.799999999996
# 3801.4
# 140.10000000000002
# 3239.9
# 6062.0
# 62744.7
# 2854.0
# 745.3
# 660.3
# 2446.5
# 5794.700000000001
# 1169.8999999999999
# 39.800000000000004
# 152.0
# 563.7000000000002
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29821 entries, 0 to 29476
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  29821 non-null  int64
#  1   Geographic area        29821 non-null  object
#  2   City                   29821 non-null  object
#  3   share_white            29821 non-null  object
#  4   share_black            29821 non-null  object
#  5   share_native_american  29821 non-null  object
#  6   share_asian            29821 non-null  object
#  7   share_hispanic         29821 non-null  object
#  8   city                   29821 non-null  object
#  9   Median Income          27418 non-null  object
#  10  poverty_rate           29128 non-null  object
#  11  percent_completed_hs   29132 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 3.0+ MB
# None
#        index Geographic area                    City share_white share_black  \
# 0          0              AK               Adak city        19.6         4.0
# 1          1              AK             Akhiok city         8.5         1.4
# 2          2              AK            Akiachak CDP         3.5         0.2
# 3          3              AK              Akiak city         5.2         0.0
# 4          4              AK             Akutan city        23.3        17.9
# ...      ...             ...                     ...         ...         ...
# 29472  29472              WY  Woods Landing-Jelm CDP        95.9         0.0
# 29473  29473              WY            Worland city        89.9         0.3
# 29474  29474              WY             Wright town        94.5         0.1
# 29475  29475              WY           Y-O Ranch CDP        92.8         1.5
# 29476  29476              WY              Yoder town        97.4         0.0
#
#       share_native_american share_asian share_hispanic  \
# 0                       5.5        52.5            8.9
# 1                      50.7         1.4           11.3
# 2                      95.1         0.2            0.2
# 3                      92.8         0.0            0.3
# 4                       5.5        43.3           20.8
# ...                     ...         ...            ...
# 29472                   0.0         2.1            0.0
# 29473                   1.3         0.6           16.6
# 29474                   1.4         0.2            6.2
# 29475                   2.6         0.0           11.8
# 29476                   0.0         0.0            4.0
#
#                             city Median Income poverty_rate  \
# 0                   AK-Adak city         78500         39.3
# 1                 AK-Akhiok city         26250         40.5
# 2                AK-Akiachak CDP         38750         26.1
# 3                  AK-Akiak city         42000         31.3
# 4                 AK-Akutan city         24750         16.1
# ...                          ...           ...          ...
# 29472  WY-Woods Landing-Jelm CDP           NaN         18.6
# 29473            WY-Worland city         41523         15.3
# 29474             WY-Wright town         77114          5.9
# 29475           WY-Y-O Ranch CDP           NaN            0
# 29476              WY-Yoder town         37500          5.4
#
#       percent_completed_hs
# 0                     93.4
# 1                     62.5
# 2                     76.7
# 3                     81.3
# 4                       73
# ...                    ...
# 29472                  100
# 29473                 85.6
# 29474                 89.2
# 29475                  100
# 29476                 79.4
#
# [29821 rows x 12 columns]

# %%
df_temp['Median Income'] = pd.to_numeric(df_temp['Median Income'], errors='coerce')
df_temp['poverty_rate'] = pd.to_numeric(df_temp['poverty_rate'], errors='coerce')
df_temp['percent_completed_hs'] = pd.to_numeric(df_temp['percent_completed_hs'], errors='coerce')
for state in list_states:
    state_df = df_temp.loc[df_temp['Geographic area'] == state]
    state_df['Median Income'] = state_df['Median Income'].fillna(state_df['Median Income'].mean())
    state_df['poverty_rate'] = state_df['poverty_rate'].fillna(state_df['poverty_rate'].mean())
    state_df['percent_completed_hs'] =state_df['percent_completed_hs'].fillna(state_df['percent_completed_hs'].mean())
    df_temp.loc[df_temp['Geographic area'] == state] = state_df
print(df_temp.info())

df_temp
# Out:
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\3410407094.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_df['Median Income'] = state_df['Median Income'].fillna(state_df['Median Income'].mean())
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\3410407094.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_df['poverty_rate'] = state_df['poverty_rate'].fillna(state_df['poverty_rate'].mean())
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\3410407094.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_df['percent_completed_hs'] =state_df['percent_completed_hs'].fillna(state_df['percent_completed_hs'].mean())
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29821 entries, 0 to 29476
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  29821 non-null  int64
#  1   Geographic area        29821 non-null  object
#  2   City                   29821 non-null  object
#  3   share_white            29821 non-null  object
#  4   share_black            29821 non-null  object
#  5   share_native_american  29821 non-null  object
#  6   share_asian            29821 non-null  object
#  7   share_hispanic         29821 non-null  object
#  8   city                   29821 non-null  object
#  9   Median Income          29821 non-null  float64
#  10  poverty_rate           29821 non-null  float64
#  11  percent_completed_hs   29821 non-null  float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 3.0+ MB
# None
#        index Geographic area                    City share_white share_black  \
# 0          0              AK               Adak city        19.6         4.0
# 1          1              AK             Akhiok city         8.5         1.4
# 2          2              AK            Akiachak CDP         3.5         0.2
# 3          3              AK              Akiak city         5.2         0.0
# 4          4              AK             Akutan city        23.3        17.9
# ...      ...             ...                     ...         ...         ...
# 29472  29472              WY  Woods Landing-Jelm CDP        95.9         0.0
# 29473  29473              WY            Worland city        89.9         0.3
# 29474  29474              WY             Wright town        94.5         0.1
# 29475  29475              WY           Y-O Ranch CDP        92.8         1.5
# 29476  29476              WY              Yoder town        97.4         0.0
#
#       share_native_american share_asian share_hispanic  \
# 0                       5.5        52.5            8.9
# 1                      50.7         1.4           11.3
# 2                      95.1         0.2            0.2
# 3                      92.8         0.0            0.3
# 4                       5.5        43.3           20.8
# ...                     ...         ...            ...
# 29472                   0.0         2.1            0.0
# 29473                   1.3         0.6           16.6
# 29474                   1.4         0.2            6.2
# 29475                   2.6         0.0           11.8
# 29476                   0.0         0.0            4.0
#
#                             city  Median Income  poverty_rate  \
# 0                   AK-Adak city   78500.000000          39.3
# 1                 AK-Akhiok city   26250.000000          40.5
# 2                AK-Akiachak CDP   38750.000000          26.1
# 3                  AK-Akiak city   42000.000000          31.3
# 4                 AK-Akutan city   24750.000000          16.1
# ...                          ...            ...           ...
# 29472  WY-Woods Landing-Jelm CDP   60874.993464          18.6
# 29473            WY-Worland city   41523.000000          15.3
# 29474             WY-Wright town   77114.000000           5.9
# 29475           WY-Y-O Ranch CDP   60874.993464           0.0
# 29476              WY-Yoder town   37500.000000           5.4
#
#        percent_completed_hs
# 0                      93.4
# 1                      62.5
# 2                      76.7
# 3                      81.3
# 4                      73.0
# ...                     ...
# 29472                 100.0
# 29473                  85.6
# 29474                  89.2
# 29475                 100.0
# 29476                  79.4
#
# [29821 rows x 12 columns]

# %%
#make a list of df fT-oubaor each city
list_df_cities = []
for i in cities:
    list_df_cities.append(df_total.loc[df_total['city'] == i])

# %%
#make a list of race
races = df_total['race'].tolist()
races =list(set(races))
races = races[1::]
races
# Out:
# ['A', 'W', 'O', 'N', 'H', 'B']

# %%
mode_total = df_total['race'].mode(dropna=True).tolist()
print(mode_total)
for i in list_df_cities:
    mode = i['race'].mode(dropna=True)
    if(len(mode) == 0):
        i[['race']] = i[['race']].fillna(mode_total[0])
        if(i['race'].isnull().sum() != 0):
            print("null val")
    elif(isinstance(mode, type(i['race']))):
        mode.dropna()
        mode = mode.tolist()
        #if the mode has more than one value then take a random choice between the values
        i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))



    df_total.loc[df_total['city'] ==  i.at[i.first_valid_index(),'city']] = i
df_total.info()
# Out:
# ['W']
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(mode_total[0])
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(mode_total[0])
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(mode_total[0])
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(mode_total[0])
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(mode_total[0])
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(mode_total[0])
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(mode_total[0])
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(mode_total[0])
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(mode_total[0])
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(mode_total[0])
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(mode_total[0])
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(mode_total[0])
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2535 entries, 0 to 2534
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2535 non-null   int64
#  1   name                     2535 non-null   object
#  2   date                     2535 non-null   object
#  3   manner_of_death          2535 non-null   object
#  4   armed                    2526 non-null   object
#  5   age                      2458 non-null   float64
#  6   gender                   2535 non-null   object
#  7   race                     2535 non-null   object
#  8   city                     2535 non-null   object
#  9   state                    2535 non-null   object
#  10  signs_of_mental_illness  2535 non-null   bool
#  11  threat_level             2535 non-null   object
#  12  flee                     2470 non-null   object
#  13  body_camera              2535 non-null   bool
# dtypes: bool(2), float64(1), int64(1), object(10)
# memory usage: 242.7+ KB
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(mode_total[0])
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(mode_total[0])
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(mode_total[0])
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(random.choice(tuple(mode)))
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\1943717575.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[['race']] = i[['race']].fillna(mode_total[0])

# %%
 # removed all data with NaN in race Column...df_training[df_training['race'].isnull()]
df_total
# Out:
#         id                name      date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  02/01/15              shot         gun  53.0
# 1        4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2        5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4        9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
# ...    ...                 ...       ...               ...         ...   ...
# 2530  2822    Rodney E. Jacobs  28/07/17              shot         gun  31.0
# 2531  2813               TK TK  28/07/17              shot     vehicle   NaN
# 2532  2818  Dennis W. Robinson  29/07/17              shot         gun  48.0
# 2533  2817       Isaiah Tucker  31/07/17              shot     vehicle  28.0
# 2534  2815        Dwayne Jeune  31/07/17              shot       knife  32.0
#
#      gender race              city state  signs_of_mental_illness  \
# 0         M    A        WA-Shelton    WA                     True
# 1         M    W          OR-Aloha    OR                    False
# 2         M    H        KS-Wichita    KS                    False
# 3         M    W  CA-San Francisco    CA                     True
# 4         M    H          CO-Evans    CO                    False
# ...     ...  ...               ...   ...                      ...
# 2530      M    B    MO-Kansas City    MO                    False
# 2531      M    H    NM-Albuquerque    NM                    False
# 2532      M    W          ID-Melba    ID                    False
# 2533      M    B        WI-Oshkosh    WI                    False
# 2534      M    B       NY-Brooklyn    NY                     True
#
#      threat_level         flee  body_camera
# 0          attack  Not fleeing        False
# 1          attack  Not fleeing        False
# 2           other  Not fleeing        False
# 3          attack  Not fleeing        False
# 4          attack  Not fleeing        False
# ...           ...          ...          ...
# 2530       attack  Not fleeing        False
# 2531       attack          Car        False
# 2532       attack          Car        False
# 2533       attack          Car         True
# 2534       attack  Not fleeing        False
#
# [2535 rows x 14 columns]

# %%
"""
We noticed that some of the 'age' data is missing.
So we imputed the average age of the people in each city and imputed the average age for the missing ages based on their city.
1. We calculate the total mean age of our total data sample.
2. We group by city, then calculate the mean Age at each city.
3. For each NaN age, we impute the mean age of that city. If that city was not calcuated (meaning this data is the only one from that city), we will use the total mean age.
"""
age_fix = df_total[['id','age','city']].copy()
age_fix = age_fix[age_fix['age'].isnull()].copy()
# 1. Calculate Total Mean Age
total_mean_age = df_total['age'].mean()

# 2. Calculate Mean of Each City
city_mean_ages = df_total.groupby('city')['age'].mean()

#3. Impute Age by the city. If City data does not exist, use Total Mean Age.
for i in age_fix.index:
    city = age_fix['city'][i]
    if city in city_mean_ages and not np.isnan(city_mean_ages[city]):
        age_fix['age'][i] = city_mean_ages[city]
    else:
        age_fix['age'][i] = total_mean_age


# update total list
df_total.update(age_fix)

df_total.info()
# Out:
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\3604504041.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age_fix['age'][i] = city_mean_ages[city]
# C:\Users\eshak\AppData\Local\Temp\ipykernel_27204\3604504041.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age_fix['age'][i] = total_mean_age
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2535 entries, 0 to 2534
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2535 non-null   float64
#  1   name                     2535 non-null   object
#  2   date                     2535 non-null   object
#  3   manner_of_death          2535 non-null   object
#  4   armed                    2526 non-null   object
#  5   age                      2535 non-null   float64
#  6   gender                   2535 non-null   object
#  7   race                     2535 non-null   object
#  8   city                     2535 non-null   object
#  9   state                    2535 non-null   object
#  10  signs_of_mental_illness  2535 non-null   bool
#  11  threat_level             2535 non-null   object
#  12  flee                     2470 non-null   object
#  13  body_camera              2535 non-null   bool
# dtypes: bool(2), float64(2), object(10)
# memory usage: 242.7+ KB

# %%
"""
We noticed there were missing values for 'armed' and 'flee'. For these, we imputed the most frequent data that appeared.
These are listed in the variables flee_mode and armed_mode
"""
flee_mode = df_total['flee'].agg(pd.Series.mode).values.tolist()[0]
armed_mode = df_total['armed'].agg(pd.Series.mode).values.tolist()[0]
df_total['flee'].fillna(flee_mode, inplace=True)
df_total['armed'].fillna(armed_mode, inplace=True)
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2535 entries, 0 to 2534
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2535 non-null   float64
#  1   name                     2535 non-null   object
#  2   date                     2535 non-null   object
#  3   manner_of_death          2535 non-null   object
#  4   armed                    2535 non-null   object
#  5   age                      2535 non-null   float64
#  6   gender                   2535 non-null   object
#  7   race                     2535 non-null   object
#  8   city                     2535 non-null   object
#  9   state                    2535 non-null   object
#  10  signs_of_mental_illness  2535 non-null   bool
#  11  threat_level             2535 non-null   object
#  12  flee                     2535 non-null   object
#  13  body_camera              2535 non-null   bool
# dtypes: bool(2), float64(2), object(10)
# memory usage: 242.7+ KB

# %%
"""
****GIVE EXPLANATION OF OUR ENTIRE PROCESS
########################### END OF DATA MUNGING##########################
"""
# Out:
# '\n****GIVE EXPLANATION OF OUR ENTIRE PROCESS\n########################### END OF DATA MUNGING##########################\n'

# %%
"""
Data Analysis
Exploratory Data Analysis (EDA 10 Points)
"""
df_total
# Out:
#           id                name      date   manner_of_death       armed  \
# 0        3.0          Tim Elliot  02/01/15              shot         gun
# 1        4.0    Lewis Lee Lembke  02/01/15              shot         gun
# 2        5.0  John Paul Quintero  03/01/15  shot and Tasered     unarmed
# 3        8.0     Matthew Hoffman  04/01/15              shot  toy weapon
# 4        9.0   Michael Rodriguez  04/01/15              shot    nail gun
# ...      ...                 ...       ...               ...         ...
# 2530  2822.0    Rodney E. Jacobs  28/07/17              shot         gun
# 2531  2813.0               TK TK  28/07/17              shot     vehicle
# 2532  2818.0  Dennis W. Robinson  29/07/17              shot         gun
# 2533  2817.0       Isaiah Tucker  31/07/17              shot     vehicle
# 2534  2815.0        Dwayne Jeune  31/07/17              shot       knife
#
#             age gender race              city state  signs_of_mental_illness  \
# 0     53.000000      M    A        WA-Shelton    WA                     True
# 1     47.000000      M    W          OR-Aloha    OR                    False
# 2     23.000000      M    H        KS-Wichita    KS                    False
# 3     32.000000      M    W  CA-San Francisco    CA                     True
# 4     39.000000      M    H          CO-Evans    CO                    False
# ...         ...    ...  ...               ...   ...                      ...
# 2530  31.000000      M    B    MO-Kansas City    MO                    False
# 2531  31.153846      M    H    NM-Albuquerque    NM                    False
# 2532  48.000000      M    W          ID-Melba    ID                    False
# 2533  28.000000      M    B        WI-Oshkosh    WI                    False
# 2534  32.000000      M    B       NY-Brooklyn    NY                     True
#
#      threat_level         flee  body_camera
# 0          attack  Not fleeing        False
# 1          attack  Not fleeing        False
# 2           other  Not fleeing        False
# 3          attack  Not fleeing        False
# 4          attack  Not fleeing        False
# ...           ...          ...          ...
# 2530       attack  Not fleeing        False
# 2531       attack          Car        False
# 2532       attack          Car        False
# 2533       attack          Car         True
# 2534       attack  Not fleeing        False
#
# [2535 rows x 14 columns]

# %%
"""
Q: Which state has the most fatal police shootings? Which city is the most dangerous?
Create a collapsed dataframe of state. Create a collapsed data frame of Cities.
"""
# Make a copy of Total Data For City!
df_aux = df_total.copy()
df_aux.sort_values(by=['city'])

# The following dropped Columns are not used when data is collapsed as City
df_aux.drop(columns=['id', 'name', 'date', 'age', 'state'], inplace=True)
df_aux.set_index('city', inplace=True)
df_aux = df_aux.astype(str)
cols = df_aux.columns.tolist() # Move 'arms' to end of list
cols.append(cols.pop(cols.index('armed')))
df_aux = df_aux[cols]

# Get a list of 'df_aux' column names
aux_cols = df_aux.columns

# Get a list of the index cities (Sorted)
list_of_cities = df_aux.index.unique().tolist()
list_of_cities.sort()

# For each column, change the string such that  " 'COLUMN_NAME': + str + (s) " is the result for each string.
# This is important so that when we build/update our resulting Dataframe, it will have unique values per catagory.
for i in list_of_cities:
    for j in aux_cols:
        df_aux.at[i, j] =  j.upper() + ': ' + df_aux.at[i, j]

# Make the df_city_stats Columns
freq_list_cols = ['Total Cases']
for i in aux_cols:
    freq_list_cols = freq_list_cols + df_aux[i].unique().tolist()


# Create Dataframe to build up
df_city_stats = pd.DataFrame(index=list_of_cities, columns=freq_list_cols)
df_city_stats = df_city_stats.fillna(0)
for i in list_of_cities: # indexs
    temp = len(df_aux[df_aux.index == i])
    df_city_stats.loc[i]['Total Cases'] = temp
    for j in aux_cols:
        temp = df_aux[df_aux.index == i][j].value_counts()
        df_city_stats.loc[i].update(temp)

df_city_stats
# Out:
#               Total Cases  MANNER_OF_DEATH: shot  \
# AK-Anchorage            3                      3
# AK-Barrow               1                      1
# AK-Big Lake             1                      1
# AK-Fairbanks            5                      4
# AK-Houston              1                      1
# ...                   ...                    ...
# WY-Cheyenne             1                      1
# WY-Douglas              2                      2
# WY-Gillette             1                      0
# WY-Laramie              1                      1
# WY-Rawlins              1                      1
#
#               MANNER_OF_DEATH: shot and Tasered  GENDER: M  GENDER: F  \
# AK-Anchorage                                  0          3          0
# AK-Barrow                                     0          1          0
# AK-Big Lake                                   0          1          0
# AK-Fairbanks                                  1          5          0
# AK-Houston                                    0          0          1
# ...                                         ...        ...        ...
# WY-Cheyenne                                   0          1          0
# WY-Douglas                                    0          2          0
# WY-Gillette                                   1          0          1
# WY-Laramie                                    0          1          0
# WY-Rawlins                                    0          1          0
#
#               RACE: A  RACE: W  RACE: H  RACE: B  RACE: O  ...  \
# AK-Anchorage        0        3        0        0        0  ...
# AK-Barrow           0        0        0        0        0  ...
# AK-Big Lake         0        0        0        1        0  ...
# AK-Fairbanks        0        1        0        0        0  ...
# AK-Houston          0        0        0        0        0  ...
# ...               ...      ...      ...      ...      ...  ...
# WY-Cheyenne         0        0        0        0        0  ...
# WY-Douglas          0        1        1        0        0  ...
# WY-Gillette         0        1        0        0        0  ...
# WY-Laramie          0        1        0        0        0  ...
# WY-Rawlins          0        1        0        0        0  ...
#
#               ARMED: metal rake  ARMED: crowbar  ARMED: oar  \
# AK-Anchorage                  0               0           0
# AK-Barrow                     0               0           0
# AK-Big Lake                   0               0           0
# AK-Fairbanks                  0               0           0
# AK-Houston                    0               0           0
# ...                         ...             ...         ...
# WY-Cheyenne                   0               0           0
# WY-Douglas                    0               0           0
# WY-Gillette                   0               0           0
# WY-Laramie                    0               0           0
# WY-Rawlins                    0               0           0
#
#               ARMED: machete and gun  ARMED: tire iron  \
# AK-Anchorage                       0                 0
# AK-Barrow                          0                 0
# AK-Big Lake                        0                 0
# AK-Fairbanks                       0                 0
# AK-Houston                         0                 0
# ...                              ...               ...
# WY-Cheyenne                        0                 0
# WY-Douglas                         0                 0
# WY-Gillette                        0                 0
# WY-Laramie                         0                 0
# WY-Rawlins                         0                 0
#
#               ARMED: air conditioner  ARMED: pole and knife  \
# AK-Anchorage                       0                      0
# AK-Barrow                          0                      0
# AK-Big Lake                        0                      0
# AK-Fairbanks                       0                      0
# AK-Houston                         0                      0
# ...                              ...                    ...
# WY-Cheyenne                        0                      0
# WY-Douglas                         0                      0
# WY-Gillette                        0                      0
# WY-Laramie                         0                      0
# WY-Rawlins                         0                      0
#
#               ARMED: baseball bat and bottle  ARMED: fireworks  ARMED: pen
# AK-Anchorage                               0                 0           0
# AK-Barrow                                  0                 0           0
# AK-Big Lake                                0                 0           0
# AK-Fairbanks                               0                 0           0
# AK-Houston                                 0                 0           0
# ...                                      ...               ...         ...
# WY-Cheyenne                                0                 0           0
# WY-Douglas                                 0                 0           0
# WY-Gillette                                0                 0           0
# WY-Laramie                                 0                 0           0
# WY-Rawlins                                 0                 0           0
#
# [1534 rows x 90 columns]

# %%
# Make a copy of Total Data For State!
df_aux = df_total.copy()
df_aux.sort_values(by=['state'])

# The following dropped Columns are not used when data is collapsed as City
df_aux.drop(columns=['id', 'name', 'date', 'age', 'city'], inplace=True)
df_aux.set_index('state', inplace=True)
df_aux = df_aux.astype(str)
cols = df_aux.columns.tolist() # Move 'arms' to end of list
cols.append(cols.pop(cols.index('armed')))
df_aux = df_aux[cols]

# Get a list of 'df_aux' column names
aux_cols = df_aux.columns

# Get a list of the index state (Sorted)
list_of_states = df_aux.index.unique().tolist()
list_of_states.sort()

# For each column, change the string such that  " 'COLUMN_NAME': + str + (s) " is the result for each string.
# This is important so that when we build/update our resulting Dataframe, it will have unique values per catagory.
for i in list_of_states:
    for j in aux_cols:
        df_aux.at[i, j] =  j.upper() + ': ' + df_aux.at[i, j]

# Make the df_city_stats Columns
freq_list_cols = ['Total Cases']
for i in aux_cols:
    freq_list_cols = freq_list_cols + df_aux[i].unique().tolist()


# Create Dataframe to build up
df_state_stats = pd.DataFrame(index=list_of_states, columns=freq_list_cols)
df_state_stats = df_state_stats.fillna(0)
for i in list_of_states: # indexs
    temp = len(df_aux[df_aux.index == i])
    df_state_stats.loc[i]['Total Cases'] = temp
    for j in aux_cols:
        temp = df_aux[df_aux.index == i][j].value_counts()
        df_state_stats.loc[i].update(temp)

df_state_stats
# Out:
#     Total Cases  MANNER_OF_DEATH: shot  MANNER_OF_DEATH: shot and Tasered  \
# AK           15                     14                                  1
# AL           50                     47                                  3
# AR           26                     25                                  1
# AZ          118                    112                                  6
# CA          424                    382                                 42
# CO           74                     71                                  3
# CT            9                      8                                  1
# DC           11                     11                                  0
# DE            8                      8                                  0
# FL          154                    143                                 11
# GA           70                     63                                  7
# HI           11                     10                                  1
# IA           12                     11                                  1
# ID           17                     17                                  0
# IL           62                     58                                  4
# IN           43                     40                                  3
# KS           24                     20                                  4
# KY           43                     41                                  2
# LA           57                     55                                  2
# MA           22                     22                                  0
# MD           38                     36                                  2
# ME           13                     12                                  1
# MI           37                     34                                  3
# MN           32                     30                                  2
# MO           64                     62                                  2
# MS           23                     23                                  0
# MT           11                     10                                  1
# NC           69                     64                                  5
# ND            4                      4                                  0
# NE           15                     13                                  2
# NH            7                      7                                  0
# NJ           35                     35                                  0
# NM           51                     50                                  1
# NV           42                     37                                  5
# NY           45                     41                                  4
# OH           79                     77                                  2
# OK           78                     69                                  9
# OR           38                     35                                  3
# PA           51                     42                                  9
# RI            2                      2                                  0
# SC           44                     42                                  2
# SD           10                     10                                  0
# TN           59                     58                                  1
# TX          225                    209                                 16
# UT           23                     23                                  0
# VA           47                     46                                  1
# VT            3                      2                                  1
# WA           62                     56                                  6
# WI           43                     42                                  1
# WV           27                     27                                  0
# WY            8                      7                                  1
#
#     GENDER: M  GENDER: F  RACE: A  RACE: W  RACE: H  RACE: B  RACE: O  ...  \
# AK         14          1        0        7        0        1        0  ...
# AL         46          4        0       36        0       14        0  ...
# AR         26          0        0       19        0        7        0  ...
# AZ        108         10        0       67       38        5        0  ...
# CA        402         22       17      146      185       66        9  ...
# CO         72          2        2       39       23        9        0  ...
# CT          9          0        0        7        2        0        0  ...
# DC          9          2        0        1        0       10        0  ...
# DE          8          0        0        4        0        4        0  ...
# FL        148          6        1       83       18       50        2  ...
# GA         67          3        1       38        6       25        0  ...
# HI         11          0        2        1        0        1        7  ...
# IA         10          2        0        9        0        3        0  ...
# ID         17          0        0       13        4        0        0  ...
# IL         60          2        0       19        7       36        0  ...
# IN         42          1        0       27        3       13        0  ...
# KS         23          1        0       19        3        2        0  ...
# KY         43          0        0       35        2        6        0  ...
# LA         57          0        2       22        0       33        0  ...
# MA         22          0        0       10        5        7        0  ...
# MD         34          4        0       14        0       24        0  ...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1534 entries, 0 to 1533
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Geographic area        1534 non-null   object
#  1   City                   1534 non-null   object
#  2   share_white            1534 non-null   object
#  3   share_black            1534 non-null   object
#  4   share_native_american  1534 non-null   object
#  5   share_asian            1534 non-null   object
#  6   share_hispanic         1534 non-null   object
#  7   city                   1534 non-null   object
#  8   Median Income          1534 non-null   object
#  9   poverty_rate           1534 non-null   object
#  10  percent_completed_hs   1534 non-null   object
#  11  index                  1534 non-null   float64
# dtypes: float64(1), object(11)
# memory usage: 155.8+ KB
# None
# 1534
#      Geographic area       City share_white share_black share_native_american  \
# 0                 AK  Anchorage        66.0         5.6                   7.9
# 1                 AK     Barrow        16.9         1.0                  61.2
# 2                 AK   Big Lake        86.1         0.2                   7.0
# 3                 AK  Fairbanks        66.1         9.0                  10.0
# 4                 AK    Houston        82.2         0.4                   6.7
# ...              ...        ...         ...         ...                   ...
# 1529              WY   Cheyenne        87.4         2.9                   1.0
# 1530              WY    Douglas        94.4         0.3                   0.8
# 1531              WY   Gillette        92.2         0.4                   1.2
# 1532              WY    Laramie        89.5         1.3                   0.7
# 1533              WY    Rawlins        84.7         1.1                   1.3
#
#      share_asian share_hispanic          city Median Income poverty_rate  \
# 0            8.1            7.6  AK-Anchorage       78326.0          8.2
# 1            9.1            3.1     AK-Barrow       76902.0         11.7
# 2            0.5            3.1   AK-Big Lake       70988.0          9.6
# 3            3.6            9.0  AK-Fairbanks       55229.0         13.1
# 4            0.6            3.3    AK-Houston       50438.0         14.8
# ...          ...            ...           ...           ...          ...
# 1529         1.2           14.5   WY-Cheyenne       58219.0         11.2
# 1530         0.2            7.6    WY-Douglas       60060.0          9.2
# 1531         0.7            9.5   WY-Gillette       74165.0          9.0
# 1532         3.2            9.2    WY-Laramie       39371.0         30.0
# 1533         1.0           24.3    WY-Rawlins       56838.0         15.7
#
#      percent_completed_hs    index
# 0                    93.0     14.0
# 1                    84.6     25.0
# 2                    90.4     32.0
# 3                    91.2     95.0
# 4                    90.2    135.0
# ...                   ...      ...
# 1529                 93.4  29312.0
# 1530                 91.2  29327.0
# 1531                 90.4  29350.0
# 1532                 96.7  29383.0
# 1533                 88.3  29428.0
#
# [1534 rows x 12 columns]

# %%
"""
Q: Which state has the most fatal police shootings? Which city is the most dangerous?
Create a collapsed dataframe of state. Create a collapsed data frame of Cities.
"""
# Make a copy of Total Data For City!
df_aux = df_total.copy()
df_aux.sort_values(by=['city'])

# The following dropped Columns are not used when data is collapsed as City
df_aux.drop(columns=['id', 'name', 'date', 'age', 'state'], inplace=True)
df_aux.set_index('city', inplace=True)
df_aux = df_aux.astype(str)
cols = df_aux.columns.tolist() # Move 'arms' to end of list
cols.append(cols.pop(cols.index('armed')))
df_aux = df_aux[cols]

# Get a list of 'df_aux' column names
aux_cols = df_aux.columns

# Get a list of the index cities (Sorted)
list_of_cities = df_aux.index.unique().tolist()
list_of_cities.sort()

# For each column, change the string such that  " 'COLUMN_NAME': + str + (s) " is the result for each string.
# This is important so that when we build/update our resulting Dataframe, it will have unique values per catagory.
for i in list_of_cities:
    for j in aux_cols:
        df_aux.at[i, j] =  j.upper() + ': ' + df_aux.at[i, j]

# Make the df_city_stats Columns
freq_list_cols = ['Total Cases']
for i in aux_cols:
    freq_list_cols = freq_list_cols + df_aux[i].unique().tolist()


# Create Dataframe to build up
df_city_stats = pd.DataFrame(index=list_of_cities, columns=freq_list_cols)
df_city_stats = df_city_stats.fillna(0)
for i in list_of_cities: # indexs
    temp = len(df_aux[df_aux.index == i])
    df_city_stats.loc[i]['Total Cases'] = temp
    for j in aux_cols:
        temp = df_aux[df_aux.index == i][j].value_counts()
        df_city_stats.loc[i].update(temp)

df_city_stats
# Out:
#               Total Cases  MANNER_OF_DEATH: shot  \
# AK-Anchorage            3                      3
# AK-Barrow               1                      1
# AK-Big Lake             1                      1
# AK-Fairbanks            5                      4
# AK-Houston              1                      1
# ...                   ...                    ...
# WY-Cheyenne             1                      1
# WY-Douglas              2                      2
# WY-Gillette             1                      0
# WY-Laramie              1                      1
# WY-Rawlins              1                      1
#
#               MANNER_OF_DEATH: shot and Tasered  GENDER: M  GENDER: F  \
# AK-Anchorage                                  0          3          0
# AK-Barrow                                     0          1          0
# AK-Big Lake                                   0          1          0
# AK-Fairbanks                                  1          5          0
# AK-Houston                                    0          0          1
# ...                                         ...        ...        ...
# WY-Cheyenne                                   0          1          0
# WY-Douglas                                    0          2          0
# WY-Gillette                                   1          0          1
# WY-Laramie                                    0          1          0
# WY-Rawlins                                    0          1          0
#
#               RACE: A  RACE: W  RACE: H  RACE: B  RACE: O  ...  \
# AK-Anchorage        0        3        0        0        0  ...
# AK-Barrow           0        0        0        0        0  ...
# AK-Big Lake         0        0        0        1        0  ...
# AK-Fairbanks        0        1        0        0        0  ...
# AK-Houston          0        0        0        0        0  ...
# ...               ...      ...      ...      ...      ...  ...
# WY-Cheyenne         0        0        0        0        0  ...
# WY-Douglas          0        1        1        0        0  ...
# WY-Gillette         0        1        0        0        0  ...
# WY-Laramie          0        1        0        0        0  ...
# WY-Rawlins          0        1        0        0        0  ...
#
#               ARMED: metal rake  ARMED: crowbar  ARMED: oar  \
# AK-Anchorage                  0               0           0
# AK-Barrow                     0               0           0
# AK-Big Lake                   0               0           0
# AK-Fairbanks                  0               0           0
# AK-Houston                    0               0           0
# ...                         ...             ...         ...
# WY-Cheyenne                   0               0           0
# WY-Douglas                    0               0           0
# WY-Gillette                   0               0           0
# WY-Laramie                    0               0           0
# WY-Rawlins                    0               0           0
#
#               ARMED: machete and gun  ARMED: tire iron  \
# AK-Anchorage                       0                 0
# AK-Barrow                          0                 0
# AK-Big Lake                        0                 0
# AK-Fairbanks                       0                 0
# AK-Houston                         0                 0
# ...                              ...               ...
# WY-Cheyenne                        0                 0
# WY-Douglas                         0                 0
# WY-Gillette                        0                 0
# WY-Laramie                         0                 0
# WY-Rawlins                         0                 0
#
#               ARMED: air conditioner  ARMED: pole and knife  \
# AK-Anchorage                       0                      0
# AK-Barrow                          0                      0
# AK-Big Lake                        0                      0
# AK-Fairbanks                       0                      0
# AK-Houston                         0                      0
# ...                              ...                    ...
# WY-Cheyenne                        0                      0
# WY-Douglas                         0                      0
# WY-Gillette                        0                      0
# WY-Laramie                         0                      0
# WY-Rawlins                         0                      0
#
#               ARMED: baseball bat and bottle  ARMED: fireworks  ARMED: pen
# AK-Anchorage                               0                 0           0
# AK-Barrow                                  0                 0           0
# AK-Big Lake                                0                 0           0
# AK-Fairbanks                               0                 0           0
# AK-Houston                                 0                 0           0
# ...                                      ...               ...         ...
# WY-Cheyenne                                0                 0           0
# WY-Douglas                                 0                 0           0
# WY-Gillette                                0                 0           0
# WY-Laramie                                 0                 0           0
# WY-Rawlins                                 0                 0           0
#
# [1534 rows x 90 columns]

# %%
df_city_stats.columns.tolist()
# Out:
# ['Total Cases',
#  'MANNER_OF_DEATH: shot',
#  'MANNER_OF_DEATH: shot and Tasered',
#  'GENDER: M',
#  'GENDER: F',
#  'RACE: A',
#  'RACE: W',
#  'RACE: H',
#  'RACE: B',
#  'RACE: O',
#  'RACE: N',
#  'SIGNS_OF_MENTAL_ILLNESS: True',
#  'SIGNS_OF_MENTAL_ILLNESS: False',
#  'THREAT_LEVEL: attack',
#  'THREAT_LEVEL: other',
#  'THREAT_LEVEL: undetermined',
#  'FLEE: Not fleeing',
#  'FLEE: Car',
#  'FLEE: Foot',
#  'FLEE: Other',
#  'BODY_CAMERA: False',
#  'BODY_CAMERA: True',
#  'ARMED: gun',
#  'ARMED: unarmed',
#  'ARMED: toy weapon',
#  'ARMED: nail gun',
#  'ARMED: knife',
#  'ARMED: vehicle',
#  'ARMED: shovel',
#  'ARMED: hammer',
#  'ARMED: hatchet',
#  'ARMED: undetermined',
#  'ARMED: sword',
#  'ARMED: machete',
#  'ARMED: box cutter',
#  'ARMED: metal object',
#  'ARMED: screwdriver',
#  'ARMED: lawn mower blade',
#  'ARMED: flagpole',
#  'ARMED: guns and explosives',
#  'ARMED: cordless drill',
#  'ARMED: crossbow',
#  'ARMED: metal pole',
#  'ARMED: Taser',
#  'ARMED: metal pipe',
#  'ARMED: metal hand tool',
#  'ARMED: blunt object',
#  'ARMED: metal stick',
#  'ARMED: sharp object',
#  'ARMED: meat cleaver',
#  'ARMED: carjack',
#  'ARMED: chain',
#  "ARMED: contractor's level",
#  'ARMED: unknown weapon',
#  'ARMED: stapler',
#  'ARMED: beer bottle',
#  'ARMED: bean-bag gun',
#  'ARMED: baseball bat and fireplace poker',
#  'ARMED: straight edge razor',
#  'ARMED: gun and knife',
#  'ARMED: ax',
#  'ARMED: brick',
#  'ARMED: baseball bat',
#  'ARMED: hand torch',
#  'ARMED: chain saw',
#  'ARMED: garden tool',
#  'ARMED: scissors',
#  'ARMED: pole',
#  'ARMED: pick-axe',
#  'ARMED: flashlight',
#  'ARMED: baton',
#  'ARMED: spear',
#  'ARMED: pitchfork',
#  'ARMED: hatchet and gun',
#  'ARMED: rock',
#  'ARMED: piece of wood',
#  'ARMED: bayonet',
#  'ARMED: pipe',
#  'ARMED: glass shard',
#  'ARMED: motorcycle',
#  'ARMED: metal rake',
#  'ARMED: crowbar',
#  'ARMED: oar',
#  'ARMED: machete and gun',
#  'ARMED: tire iron',
#  'ARMED: air conditioner',
#  'ARMED: pole and knife',
#  'ARMED: baseball bat and bottle',
#  'ARMED: fireworks',
#  'ARMED: pen']

# %%
'''
The goal is to make a visualization of our data so we can find out which city in the set is the most dangerous. We can determine this by comparing the number of fatal shootings 

Create a bar graph using the df_city_stats DataFrame to visualize the trend of fatal shootings per city
'''

plt.bar(df_city_stats.index, df_city_stats['Total Cases'])
plt.title('Total Cases of Fatal Shootings by City')
plt.xlabel('City')
plt.ylabel('Number of Fatal Shootings')
plt.show()
# Out:
# C:\Users\eshak\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 150 (\x96) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
'''
The above bar graph is extremely packed and the majority of the values are very small, so they don't matter to us when trying to determine which cities have the highest number of fatal shootings. Let's repeat the process using only the cities with number of killings greater than 10. With this, we can see the data better.
'''

df_city_stats_temp = df_city_stats[df_city_stats['Total Cases'] > 10]
# df_city_stats_temp

plt.bar(df_city_stats_temp.index, df_city_stats_temp['Total Cases'])
plt.title('Total Cases of Fatal Shootings by City')
plt.xlabel('City')
plt.ylabel('Number of Fatal Shootings')
plt.show()

# %%
'''
The graph above looks a bit better, but it's still hard to distinguish the cities because of how packed the data is. We can further eliminate some data from our graph to make it easier to look at, so let's only consider those cities with number of fatal shootings above 20 and see if that works out better.
'''

df_city_stats_temp = df_city_stats[df_city_stats['Total Cases'] > 20]
# df_city_stats_temp

plt.bar(df_city_stats_temp.index, df_city_stats_temp['Total Cases'])
plt.title('Total Cases of Fatal Shootings by City')
plt.xlabel('City')
plt.ylabel('Number of Fatal Shootings')
plt.show()

# %%
'''
This graph very clearly shows that Los Angeles, CA is the city with the most fatal shootings, which we can use as our basis to claim that Los Angeles is the most dangerous of the cities on this list. It is followed closely by Phoenix, AZ and Houston, TX.
'''
# Out:
# '\nThis graph very clearly shows that Los Angeles, CA is the city with the most fatal shootings, which we can use as our basis to claim that Los Angeles is the most dangerous of the cities on this list. It is followed closely by Phoenix, AZ and Houston, TX.\n'

# %%
# Make a copy of Total Data For State!
df_aux = df_total.copy()
df_aux.sort_values(by=['state'])

# The following dropped Columns are not used when data is collapsed as City
df_aux.drop(columns=['id', 'name', 'date', 'age', 'city'], inplace=True)
df_aux.set_index('state', inplace=True)
df_aux = df_aux.astype(str)
cols = df_aux.columns.tolist() # Move 'arms' to end of list
cols.append(cols.pop(cols.index('armed')))
df_aux = df_aux[cols]

# Get a list of 'df_aux' column names
aux_cols = df_aux.columns

# Get a list of the index state (Sorted)
list_of_states = df_aux.index.unique().tolist()
list_of_states.sort()

# For each column, change the string such that  " 'COLUMN_NAME': + str + (s) " is the result for each string.
# This is important so that when we build/update our resulting Dataframe, it will have unique values per catagory.
for i in list_of_states:
    for j in aux_cols:
        df_aux.at[i, j] =  j.upper() + ': ' + df_aux.at[i, j]

# Make the df_city_stats Columns
freq_list_cols = ['Total Cases']
for i in aux_cols:
    freq_list_cols = freq_list_cols + df_aux[i].unique().tolist()


# Create Dataframe to build up
df_state_stats = pd.DataFrame(index=list_of_states, columns=freq_list_cols)
df_state_stats = df_state_stats.fillna(0)
for i in list_of_states: # indexs
    temp = len(df_aux[df_aux.index == i])
    df_state_stats.loc[i]['Total Cases'] = temp
    for j in aux_cols:
        temp = df_aux[df_aux.index == i][j].value_counts()
        df_state_stats.loc[i].update(temp)

df_state_stats
# Out:
#     Total Cases  MANNER_OF_DEATH: shot  MANNER_OF_DEATH: shot and Tasered  \
# AK           15                     14                                  1
# AL           50                     47                                  3
# AR           26                     25                                  1
# AZ          118                    112                                  6
# CA          424                    382                                 42
# CO           74                     71                                  3
# CT            9                      8                                  1
# DC           11                     11                                  0
# DE            8                      8                                  0
# FL          154                    143                                 11
# GA           70                     63                                  7
# HI           11                     10                                  1
# IA           12                     11                                  1
# ID           17                     17                                  0
# IL           62                     58                                  4
# IN           43                     40                                  3
# KS           24                     20                                  4
# KY           43                     41                                  2
# LA           57                     55                                  2
# MA           22                     22                                  0
# MD           38                     36                                  2
# ME           13                     12                                  1
# MI           37                     34                                  3
# MN           32                     30                                  2
# MO           64                     62                                  2
# MS           23                     23                                  0
# MT           11                     10                                  1
# NC           69                     64                                  5
# ND            4                      4                                  0
# NE           15                     13                                  2
# NH            7                      7                                  0
# NJ           35                     35                                  0
# NM           51                     50                                  1
# NV           42                     37                                  5
# NY           45                     41                                  4
# OH           79                     77                                  2
# OK           78                     69                                  9
# OR           38                     35                                  3
# PA           51                     42                                  9
# RI            2                      2                                  0
# SC           44                     42                                  2
# SD           10                     10                                  0
# TN           59                     58                                  1
# TX          225                    209                                 16
# UT           23                     23                                  0
# VA           47                     46                                  1
# VT            3                      2                                  1
# WA           62                     56                                  6
# WI           43                     42                                  1
# WV           27                     27                                  0
# WY            8                      7                                  1
#
#     GENDER: M  GENDER: F  RACE: A  RACE: W  RACE: H  RACE: B  RACE: O  ...  \
# AK         14          1        0        7        0        1        0  ...
# AL         46          4        0       36        0       14        0  ...
# AR         26          0        0       19        0        7        0  ...
# AZ        108         10        0       67       38        5        0  ...
# CA        402         22       17      146      185       66        9  ...
# CO         72          2        2       39       23        9        0  ...
# CT          9          0        0        7        2        0        0  ...
# DC          9          2        0        1        0       10        0  ...
# DE          8          0        0        4        0        4        0  ...
# FL        148          6        1       83       18       50        2  ...
# GA         67          3        1       38        6       25        0  ...
# HI         11          0        2        1        0        1        7  ...
# IA         10          2        0        9        0        3        0  ...
# ID         17          0        0       13        4        0        0  ...
# IL         60          2        0       19        7       36        0  ...
# IN         42          1        0       27        3       13        0  ...
# KS         23          1        0       19        3        2        0  ...
# KY         43          0        0       35        2        6        0  ...
# LA         57          0        2       22        0       33        0  ...
# MA         22          0        0       10        5        7        0  ...
# MD         34          4        0       14        0       24        0  ...
# ME         12          1        0       11        0        1        1  ...
# MI         36          1        0       21        1       15        0  ...
# MN         30          2        1       21        1        6        2  ...
# MO         61          3        0       36        2       26        0  ...
# MS         22          1        0       14        1        8        0  ...
# MT         11          0        0       11        0        0        0  ...
# NC         65          4        1       38        2       28        0  ...
# ND          4          0        0        1        0        0        0  ...
# MD                 0                       0                      0
# ME                 0                       0                      0
# MI                 0                       0                      0
# MN                 0                       1                      0
# MO                 0                       0                      0
# MS                 0                       0                      0
# MT                 0                       0                      0
# NC                 0                       0                      0
# ND                 0                       0                      0
# NE                 0                       0                      0
# NH                 0                       0                      0
# NJ                 0                       0                      0
# NM                 0                       0                      0
# NV                 0                       0                      0
# NY                 0                       0                      0
# OH                 0                       0                      0
# OK                 1                       0                      0
# OR                 0                       0                      0
# PA                 0                       0                      0
# RI                 0                       0                      0
# SC                 0                       0                      0
# SD                 0                       0                      0
# TN                 0                       0                      0
# TX                 0                       0                      0
# UT                 0                       0                      0
# VA                 0                       0                      0
# VT                 0                       0                      0
# WA                 0                       0                      0
# WI                 0                       0                      0
# WV                 0                       0                      0
# WY                 0                       0                      0
#
#     ARMED: baseball bat and bottle  ARMED: fireworks  ARMED: pen
# AK                               0                 0           0
# AL                               0                 0           0
# AR                               0                 0           0
# AZ                               0                 0           0
# CA                               1                 0           0
# CO                               0                 0           0
# CT                               0                 0           0
# DC                               0                 0           0
# DE                               0                 0           0
# FL                               0                 0           0
# GA                               0                 0           0
# HI                               0                 0           0
# IA                               0                 0           0
# ID                               0                 0           0
# IL                               0                 0           0
# IN                               0                 0           0
# KS                               0                 0           0
# KY                               0                 0           0
# LA                               0                 0           0
# MA                               0                 0           0
# MD                               0                 0           0
# ME                               0                 0           0
# MI                               0                 0           0
# MN                               0                 0           0
# MO                               0                 0           0
# MS                               0                 0           0
# MT                               0                 0           0
# NC                               0                 0           0
# ND                               0                 0           0
# NE                               0                 0           0
# NH                               0                 0           0
# NJ                               0                 0           0
# NM                               0                 0           0
# NV                               0                 0           0
# NY                               0                 0           0
# OH                               0                 0           0
# OK                               0                 0           0
# OR                               0                 0           0
# PA                               0                 1           0
# RI                               0                 0           0
# SC                               0                 0           0
# SD                               0                 0           0
# TN                               0                 0           0
# TX                               0                 0           0
# UT                               0                 0           0
# VA                               0                 0           0
# VT                               0                 0           0
# WA                               0                 0           1
# WI                               0                 0           0
# WV                               0                 0           0
# WY                               0                 0           0
#
# [51 rows x 90 columns]

# %%
'''
The goal is to make a visualization of our data so we can find out which state in the set has the most fatal police shootings

Create a bar graph using the df_state_stats DataFrame to visualize the trend of fatal shootings per state
'''

plt.bar(df_state_stats.index, df_state_stats['Total Cases'])
plt.title('Total Cases of Fatal Shootings by State')
plt.xlabel('State')
plt.ylabel('Number of Fatal Shootings')
plt.show()

# %%
'''
The above bar graph is extremely packed and the majority of the values are very small, so they don't matter to us when trying to determine which states have the highest number of fatal shootings. Let's repeat the process using only the states with number of killings greater than 50. With this, we can see the data better.
'''

df_state_stats_temp = df_state_stats[df_state_stats['Total Cases'] > 50]
# df_state_stats_temp

# plt.bar(df_state_stats_temp.index, df_state_stats_temp['Total Cases'])
# plt.title('Total Cases of Fatal Shootings by State')
# plt.xlabel('State')
# plt.ylabel('Number of Fatal Shootings')
# plt.show()

x_list = list(df_state_stats_temp.index)
y_list = list(df_state_stats_temp['Total Cases'])
plt.bar(x_list, y_list)
plt.title('Total Cases of Fatal Shootings by State')
plt.xlabel('State')
plt.ylabel('Number of Fatal Shootings')
for i in range(len(x_list)):
    plt.text(x_list[i], y_list[i], y_list[i], ha='center')
plt.show()

# %%
'''
The graph clearly shows that CA is the state with the highest number of fatal police shootings (over 400), followed by TX with slightly over 200 fatal shootings.

We can confirm this conclusion using code by extracting the maximum value of 'Total Cases' from the DataFrame and seeing which state it is associated with. 
The line of code below accomplishes this and does indeed confirm that CA is the state with the highest number of fatal shootings (424). 
'''
s = df_state_stats.loc[df_state_stats['Total Cases'].idxmax()]
s.name, s['Total Cases']
# Out:
# ('CA', 424)

# %%
df_state_stats.columns
# Out:
# Index(['Total Cases', 'MANNER_OF_DEATH: shot',
#        'MANNER_OF_DEATH: shot and Tasered', 'GENDER: M', 'GENDER: F',
#        'RACE: A', 'RACE: W', 'RACE: H', 'RACE: B', 'RACE: O', 'RACE: N',
#        'SIGNS_OF_MENTAL_ILLNESS: True', 'SIGNS_OF_MENTAL_ILLNESS: False',
#        'THREAT_LEVEL: attack', 'THREAT_LEVEL: other',
#        'THREAT_LEVEL: undetermined', 'FLEE: Not fleeing', 'FLEE: Car',
#        'FLEE: Foot', 'FLEE: Other', 'BODY_CAMERA: False', 'BODY_CAMERA: True',
#        'ARMED: gun', 'ARMED: unarmed', 'ARMED: toy weapon', 'ARMED: nail gun',
#        'ARMED: knife', 'ARMED: vehicle', 'ARMED: shovel', 'ARMED: hammer',
#        'ARMED: hatchet', 'ARMED: undetermined', 'ARMED: sword',
#        'ARMED: machete', 'ARMED: box cutter', 'ARMED: metal object',
#        'ARMED: screwdriver', 'ARMED: lawn mower blade', 'ARMED: flagpole',
#        'ARMED: guns and explosives', 'ARMED: cordless drill',
#        'ARMED: crossbow', 'ARMED: metal pole', 'ARMED: Taser',
#        'ARMED: metal pipe', 'ARMED: metal hand tool', 'ARMED: blunt object',
#        'ARMED: metal stick', 'ARMED: sharp object', 'ARMED: meat cleaver',
#        'ARMED: carjack', 'ARMED: chain', 'ARMED: contractor's level',
#        'ARMED: unknown weapon', 'ARMED: stapler', 'ARMED: beer bottle',
#        'ARMED: bean-bag gun', 'ARMED: baseball bat and fireplace poker',
#        'ARMED: straight edge razor', 'ARMED: gun and knife', 'ARMED: ax',
#        'ARMED: brick', 'ARMED: baseball bat', 'ARMED: hand torch',
#        'ARMED: chain saw', 'ARMED: garden tool', 'ARMED: scissors',
#        'ARMED: pole', 'ARMED: pick-axe', 'ARMED: flashlight', 'ARMED: baton',
#        'ARMED: spear', 'ARMED: pitchfork', 'ARMED: hatchet and gun',
#        'ARMED: rock', 'ARMED: piece of wood', 'ARMED: bayonet', 'ARMED: pipe',
#        'ARMED: glass shard', 'ARMED: motorcycle', 'ARMED: metal rake',
#        'ARMED: crowbar', 'ARMED: oar', 'ARMED: machete and gun',
#        'ARMED: tire iron', 'ARMED: air conditioner', 'ARMED: pole and knife',
#        'ARMED: baseball bat and bottle', 'ARMED: fireworks', 'ARMED: pen'],
#       dtype='object')

# %%
'''
The goal is to find out what the most common way of being armed is. We can do this by iterating through every index and sum up the values in each column for method of arms

We can store the results in a dictionary
'''

armed_counts = dict()
armed_cols = [c for c in df_state_stats.columns if c[0:5] == "ARMED"]

for index, row in df_state_stats.iterrows():
    for col in armed_cols:
        arm_type = col[7:]
        armed_counts[arm_type] = armed_counts.get(arm_type, 0) + row[col]

'''
Now the armed_counts dictionary contains each way of being armed along with its corresponding number of appearances.

We can sort the dictionary by value in non-increasing order to determine what the most common ways of being armed are.

By doing this, we can see that the most common way of being armed is with a gun (1407 occurrences), followed by knife with 373 occurrences.
'''

armed_counts_list = sorted(armed_counts.items(), key=lambda x:x[1], reverse=True)
armed_counts_list
# Out:
# [('gun', 1407),
#  ('knife', 373),
#  ('vehicle', 177),
#  ('unarmed', 171),
#  ('undetermined', 117),
#  ('toy weapon', 104),
#  ('machete', 18),
#  ('unknown weapon', 18),
#  ('Taser', 9),
#  ('ax', 9),
#  ('sword', 8),
#  ('baseball bat', 8),
#  ('hammer', 7),
#  ('box cutter', 7),
#  ('metal pipe', 7),
#  ('hatchet', 6),
#  ('crossbow', 6),
#  ('screwdriver', 5),
#  ('blunt object', 5),
#  ('gun and knife', 5),
#  ('guns and explosives', 3),
#  ('metal stick', 3),
#  ('scissors', 3),
#  ('rock', 3),
#  ('shovel', 2),
#  ('metal object', 2),
#  ('metal pole', 2),
#  ('sharp object', 2),
#  ('meat cleaver', 2),
#  ('beer bottle', 2),
#  ('brick', 2),
#  ('chain saw', 2),
#  ('baton', 2),
#  ('hatchet and gun', 2),
#  ('piece of wood', 2),
#  ('pipe', 2),
#  ('nail gun', 1),
#  ('lawn mower blade', 1),
#  ('flagpole', 1),
#  ('cordless drill', 1),
#  ('metal hand tool', 1),
#  ('carjack', 1),
#  ('chain', 1),
#  ("contractor's level", 1),
#  ('stapler', 1),
#  ('bean-bag gun', 1),
#  ('baseball bat and fireplace poker', 1),
#  ('straight edge razor', 1),
#  ('hand torch', 1),
#  ('garden tool', 1),
#  ('pole', 1),
#  ('pick-axe', 1),
#  ('flashlight', 1),
#  ('spear', 1),
#  ('pitchfork', 1),
#  ('bayonet', 1),
#  ('glass shard', 1),
#  ('motorcycle', 1),
#  ('metal rake', 1),
#  ('crowbar', 1),
#  ('oar', 1),
#  ('machete and gun', 1),
#  ('tire iron', 1),
#  ('air conditioner', 1),
#  ('pole and knife', 1),
#  ('baseball bat and bottle', 1),
#  ('fireworks', 1),
#  ('pen', 1)]

# %%
'''
We can also use a bar graph to visualize this data.
'''
plt.bar(armed_counts.keys(), armed_counts.values())
plt.title("Number of Occurrences for Each Method of being Armed")
plt.xlabel("Method of Arms")
plt.ylabel("Number of Occurrences")
plt.show()

# %%
armed_counts_reduced = dict()

for tup in armed_counts_list:
    if (tup[1] > 10):
        armed_counts_reduced[tup[0]] = tup[1]

armed_counts_reduced
# Out:
# {'gun': 1407,
#  'knife': 373,
#  'vehicle': 177,
#  'unarmed': 171,
#  'undetermined': 117,
#  'toy weapon': 104,
#  'machete': 18,
#  'unknown weapon': 18}

# %%
'''
We can also use a bar graph to visualize this data.
'''
# plt.bar(armed_counts_reduced.keys(), armed_counts_reduced.values())
# plt.title("Number of Occurrences for Each Method of being Armed")
# plt.xlabel("Method of Arms")
# plt.ylabel("Number of Occurrences")
# plt.show()


x_list = list(armed_counts_reduced.keys())
y_list = list(armed_counts_reduced.values())
plt.bar(x_list, y_list)
plt.title("Number of Occurrences for Each Method of being Armed")
plt.xlabel("Method of Arms")
plt.ylabel("Number of Occurrences")
for i in range(len(x_list)):
    plt.text(x_list[i], y_list[i], y_list[i], ha='center')
plt.show()

# %%
'''
The graph above clearly shows that guns are the most common by a very wide margin, followed by knives in second and then vehicles in third place.
Interestingly, we can also see here that the 4th most common occurrence is actually "unarmed" - no weapons/items 
'''
# Out:
# '\nThe graph above clearly shows that guns are the most common by a very wide margin, followed by knives in second and then vehicles in third place.\nInterestingly, we can also see here that the 4th most common occurrence is actually "unarmed" - no weapons/items \n'

# %%
'''
Now let's look at the age distribution of all the victims
'''

all_hist = sb.histplot(df_total['age'], bins=20, binrange=(0,100))
all_hist.set_title("Age Distribution of All Victims")
# Out:
# Text(0.5, 1.0, 'Age Distribution of All Victims')

# %%
df_a = df_total[df_total['race'] == 'A']
a_hist = sb.histplot(df_a['age'], bins=20, binrange=(0,100))
a_hist.set_title("Age Distribution of Asian Victims")
# Out:
# Text(0.5, 1.0, 'Age Distribution of Asian Victims')

# %%
df_w = df_total[df_total['race'] == 'W']
w_hist = sb.histplot(df_w['age'], bins=20, binrange=(0,100))
w_hist.set_title("Age Distribution of White Victims")
# Out:
# Text(0.5, 1.0, 'Age Distribution of White Victims')

# %%
df_b = df_total[df_total['race'] == 'B']
b_hist = sb.histplot(df_b['age'], bins=20, binrange=(0,100))
b_hist.set_title("Age Distribution of Black Victims")
# Out:
# Text(0.5, 1.0, 'Age Distribution of Black Victims')

# %%
df_h = df_total[df_total['race'] == 'H']
a_hist = sb.histplot(df_h['age'], bins=20, binrange=(0,100))
a_hist.set_title("Age Distribution of Hispanic Victims")
# Out:
# Text(0.5, 1.0, 'Age Distribution of Hispanic Victims')

# %%
df_n = df_total[df_total['race'] == 'N']
a_hist = sb.histplot(df_n['age'], bins=20, binrange=(0,100))
a_hist.set_title("Age Distribution of Native American Victims")
# Out:
# Text(0.5, 1.0, 'Age Distribution of Native American Victims')

# %%
df_o = df_total[df_total['race'] == 'O']
a_hist = sb.histplot(df_o['age'], bins=20, binrange=(0,100))
a_hist.set_title("Age Distribution of Other Race Victims")
# Out:
# Text(0.5, 1.0, 'Age Distribution of Other Race Victims')

# %%
'''
Now let's graph the means and medians of the ages for each race and compare them
'''


races = ["Asian", "White", "Black", "Hispanic", "Natives", "Other"]
# mean_list, median_list = [], []
mean_list = [df_a['age'].mean()] + [df_w['age'].mean()] + [df_b['age'].mean()] + [df_h['age'].mean()] + [df_n['age'].mean()] + [df_o['age'].mean()]
median_list = [df_a['age'].median()] + [df_w['age'].median()] + [df_b['age'].median()] + [df_h['age'].median()] + [df_n['age'].median()] + [df_o['age'].median()]

x_axis = np.arange(len(races))

plt.bar(x_axis - 0.2, mean_list, width = 0.4, label = 'Mean')
plt.bar(x_axis + 0.2, median_list, width = 0.4, label = 'Median')

plt.title("Mean/Median of Ages for Each Race")
plt.xlabel("Race")
plt.ylabel("Value")

plt.xticks(x_axis, races)

plt.legend()

plt.show()

# %%
list(set(sorted(df_total['age'].unique())))
df_total['race'].unique()
# Out:
# array(['A', 'W', 'H', 'B', 'O', 'N'], dtype=object)

# %%
'''
Let's get the total number of people killed per race.
'''

race_count = df_total.groupby('race')['race'].size()
race_count
# Out:
# race
# A      42
# B     639
# H     449
# N      32
# O      31
# W    1342
# Name: race, dtype: int64

# %%
x_list = race_count.index.tolist()
y_list = race_count.tolist()
plt.bar(x_list, y_list)
plt.title("Number of People Killed per Race")
plt.xlabel("Race")
plt.ylabel("Number of People Killed")
for i in range(len(x_list)):
    plt.text(x_list[i], y_list[i], y_list[i], ha='center')
plt.show()

# %%
'''
Now we can find the ratio of deaths for each race over the total amount of deaths and visualize that data as well
'''

total_deaths = race_count.sum()
x_list = race_count.index.tolist()
y_list = [round((y / total_deaths), 4) for y in race_count.tolist()]
plt.bar(x_list, y_list)
plt.title("Ratio of People Killed per Race")
plt.xlabel("Race")
plt.ylabel("Ratio of People Killed")
for i in range(len(x_list)):
    plt.text(x_list[i], y_list[i], y_list[i], ha='center')
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
df_total

# %%
'''
This dictionary holds all each city in the dataset along with its corresponding median income, poverty rate, and education level. We will use this to assign each person in the dataset with a median income, poverty, and education. These additions to the data will help us later in classifying our test data. 
'''

cities_list, median_income_list, poverty_list, education_list = df_support['city'], df_support['Median Income'], df_support['poverty_rate'], df_support['percent_completed_hs']
cm_dict = {cities_list[i]: (median_income_list[i], poverty_list[i], education_list[i]) for i in range(len(cities_list))}
cm_dict

# %%
df_total_copy = df_total.copy()
df_total_copy['Median Income'] = 0
df_total_copy

# %%
df_support

# %%
df_total
# Out:
#           id                name      date   manner_of_death       armed  \
# 0        3.0          Tim Elliot  02/01/15              shot         gun
# 1        4.0    Lewis Lee Lembke  02/01/15              shot         gun
# 2        5.0  John Paul Quintero  03/01/15  shot and Tasered     unarmed
# 3        8.0     Matthew Hoffman  04/01/15              shot  toy weapon
# 4        9.0   Michael Rodriguez  04/01/15              shot    nail gun
# ...      ...                 ...       ...               ...         ...
# 2530  2822.0    Rodney E. Jacobs  28/07/17              shot         gun
# 2531  2813.0               TK TK  28/07/17              shot     vehicle
# 2532  2818.0  Dennis W. Robinson  29/07/17              shot         gun
# 2533  2817.0       Isaiah Tucker  31/07/17              shot     vehicle
# 2534  2815.0        Dwayne Jeune  31/07/17              shot       knife
#
#             age gender race              city state  signs_of_mental_illness  \
# 0     53.000000      M    A        WA-Shelton    WA                     True
# 1     47.000000      M    W          OR-Aloha    OR                    False
# 2     23.000000      M    H        KS-Wichita    KS                    False
# 3     32.000000      M    W  CA-San Francisco    CA                     True
# 4     39.000000      M    H          CO-Evans    CO                    False
# ...         ...    ...  ...               ...   ...                      ...
# 2530  31.000000      M    B    MO-Kansas City    MO                    False
# 2531  31.153846      M    H    NM-Albuquerque    NM                    False
# 2532  48.000000      M    W          ID-Melba    ID                    False
# 2533  28.000000      M    B        WI-Oshkosh    WI                    False
# 2534  32.000000      M    B       NY-Brooklyn    NY                     True
#
#      threat_level         flee  body_camera
# 0          attack  Not fleeing        False
# 1          attack  Not fleeing        False
# 2           other  Not fleeing        False
# 3          attack  Not fleeing        False
# 4          attack  Not fleeing        False
# ...           ...          ...          ...
# 2530       attack  Not fleeing        False
# 2531       attack          Car        False
# 2532       attack          Car        False
# 2533       attack          Car         True
# 2534       attack  Not fleeing        False
#
# [2535 rows x 14 columns]

# %%
'''
This dictionary holds all each city in the dataset along with its corresponding median income, poverty rate, and education level. We will use this to assign each person in the dataset with a median income, poverty, and education. These additions to the data will help us later in classifying our test data. 
'''

cities_list, median_income_list, poverty_list, education_list = df_support['city'], df_support['Median Income'], df_support['poverty_rate'], df_support['percent_completed_hs']
cm_dict = {cities_list[i]: (median_income_list[i], poverty_list[i], education_list[i]) for i in range(len(cities_list))}
cm_dict
# Out:
# {'AK-Anchorage': (78326.0, 8.2, 93.0),
#  'AK-Barrow': (76902.0, 11.7, 84.6),
#  'AK-Big Lake': (70988.0, 9.6, 90.4),
#  'AK-Fairbanks': (55229.0, 13.1, 91.2),
#  'AK-Houston': (50438.0, 14.8, 90.2),
#  'AK-Kenai Peninsula': (52099.594405594406,
#   19.85299401197605,
#   84.62738095238095),
#  'AK-Spenard': (52099.594405594406, 19.85299401197605, 84.62738095238095),
#  'AK-Wasilla': (61541.0, 11.7, 91.8),
#  'AL-Abbeville': (25615.0, 29.1, 69.1),
#  'AL-Arab': (40292.0, 16.7, 87.6),
#  'AL-Ashville': (40547.0, 28.3, 77.6),
#  'AL-Baldwin County': (40577.30952380953,
#   20.647089041095892,
#   80.30068493150684),
#  'AL-Bay Minette': (31576.0, 26.3, 79.1),
#  'AL-Birmingham': (31061.0, 30.9, 85.1),
#  'AL-Brooksville': (40577.30952380953, 20.647089041095892, 80.30068493150684),
#  'AL-Clanton': (39823.0, 16.9, 76.8),
#  'AL-Clay': (40577.30952380953, 20.647089041095892, 80.30068493150684),
#  'AL-Dadeville': (29368.0, 28.8, 73.7),
#  'AL-Deer Park': (40577.30952380953, 28.1, 86.3),
#  'AL-Eastaboga': (40577.30952380953, 20.647089041095892, 80.30068493150684),
#  'AL-Eufaula': (32845.0, 25.3, 81.5),
#  'AL-Gadsden': (29136.0, 29.4, 78.3),
#  'AL-Homewood': (61626.0, 12.7, 93.5),
#  'AL-Hoover': (77146.0, 6.0, 95.2),
#  'AL-Huntsville': (48775.0, 18.2, 90.2),
#  'AL-Jackson County': (40577.30952380953,
#   20.647089041095892,
#   80.30068493150684),
#  'AL-Killeen': (40577.30952380953, 20.647089041095892, 80.30068493150684),
#  'AL-Lawrence County': (40577.30952380953,
#   20.647089041095892,
#   80.30068493150684),
#  'AL-Macon County': (40577.30952380953, 20.647089041095892, 80.30068493150684),
#  'AL-Meridianville': (68368.0, 15.4, 86.6),
#  'AL-Millbrook': (58330.0, 11.6, 91.3),
#  'AL-Mobile': (38776.0, 23.3, 86.9),
#  'AL-Monroeville': (30678.0, 36.7, 82.3),
#  'AL-Montgomery': (42927.0, 24.1, 85.5),
#  'AL-Muscle Shoals': (48896.0, 10.7, 88.7),
#  'AL-Opelika': (40489.0, 23.0, 83.7),
#  'AL-Opp': (34695.0, 25.9, 77.4),
#  'AL-Oxford': (51375.0, 11.7, 83.5),
#  'AL-Phenix City': (36698.0, 21.0, 84.8),
#  'AL-Piedmont': (28884.0, 25.6, 76.8),
#  'AL-Rainbow City': (49338.0, 17.7, 92.5),
#  'AL-Saraland': (52621.0, 11.2, 85.4),
#  'AL-Selma': (22414.0, 41.9, 77.8),
#  'AL-Sylacauga': (33407.0, 29.8, 82.5),
#  'AL-Tuscaloosa': (39351.0, 25.1, 87.3),
#  'AL-Tuscumbia': (41176.0, 15.3, 86.2),
#  'AL-Washington County': (40577.30952380953,
#   20.647089041095892,
#   80.30068493150684),
#  'AL-Westover': (58906.0, 13.4, 85.2),
#  'AR-Austin': (70652.0, 7.7, 95.9),
#  'AR-Benton': (35593.40891472868, 22.96321626617375, 79.94953789279113),
#  'AR-Bull Shoals': (35737.0, 13.9, 93.4),
#  'AR-Cabot': (57790.0, 11.4, 92.4),
#  'AR-Desha': (35593.40891472868, 22.96321626617375, 79.94953789279113),
#  'AR-Dover': (33917.0, 23.6, 85.2),
#  'AR-England': (31577.0, 29.9, 82.3),
#  'AR-Farmington': (50609.0, 11.4, 92.3),
#  'AR-Fayetteville': (39432.0, 24.0, 91.7),
#  'AR-Jonesboro': (41688.0, 23.7, 89.1),
#  'AR-Little Rock': (46085.0, 17.8, 90.7),
#  'AR-Manila': (30114.0, 32.6, 80.7),
#  'AR-Marion': (61669.0, 10.9, 89.3),
#  'AR-Mena': (28509.0, 18.5, 88.8),
#  'AR-Mountain Pine': (31333.0, 25.0, 69.4),
#  'AR-Perryville': (37137.0, 14.0, 85.8),
#  'AR-Sheridan': (45966.0, 10.2, 90.4),
#  'AR-Sims': (35593.40891472868, 22.96321626617375, 79.94953789279113),
#  'AR-Springdale': (42319.0, 23.3, 71.7),
#  'AR-Strong': (19931.0, 23.0, 74.4),
#  'AR-West Memphis': (30627.0, 30.9, 80.6),
#  'AZ-Apache Junction': (35671.0, 24.0, 85.5),
#  'AZ-Avondale': (55100.0, 18.6, 79.0),
#  'AZ-Bisbee': (31010.0, 29.1, 87.3),
#  'AZ-Buckeye': (58939.0, 14.8, 84.3),
#  'AZ-Bullhead City': (35948.0, 19.7, 82.7),
#  'AZ-Casa Grande': (44348.0, 16.9, 86.4),
#  'AZ-Chandler': (72695.0, 10.0, 91.5),
#  'AZ-Cottonwood': (42495.666666666664, 25.666441441441446, 80.46711711711714),
#  'AZ-Eagar': (50675.0, 18.0, 89.2),
#  'AZ-Flagstaff': (48680.0, 24.2, 91.3),
#  'AZ-Florence': (47891.0, 16.8, 75.6),
#  'AZ-Gilbert': (82424.0, 6.6, 95.6),
#  'IL-Harvey': (22014.0, 36.4, 78.1),
#  'IL-Hurst': (30000.0, 15.7, 80.8),
#  'IL-Jerseyville': (50232.0, 6.4, 90.6),
#  'IL-Joilet': (54052.70614359734, 13.879780219780217, 88.48344322344322),
#  'IL-Lansing': (48949.0, 14.6, 89.5),
#  'IL-Lawndale': (54052.70614359734, 13.879780219780217, 88.48344322344322),
#  'IL-Lisle': (75373.0, 8.6, 95.5),
#  'IL-Lyons': (44534.0, 15.2, 83.1),
#  'IL-Maeystown': (50417.0, 13.2, 93.8),
#  'IL-Marion': (42839.0, 18.2, 90.3),
#  'IL-Markham': (34433.0, 25.8, 83.1),
#  'IL-Metropolis': (31875.0, 23.0, 77.2),
#  'IL-North Riverside': (59821.0, 11.2, 93.0),
#  'IL-Rantoul': (38769.0, 25.1, 86.7),
#  'IL-River Forest': (99250.0, 4.4, 96.6),
#  'IL-Rock Island': (54052.70614359734, 13.879780219780217, 88.48344322344322),
#  'IL-Rockford': (38716.0, 24.8, 83.1),
#  'IL-Round Lake': (54052.70614359734, 13.879780219780217, 88.48344322344322),
#  'IL-Shawnee National Forest': (54052.70614359734,
#   13.879780219780217,
#   88.48344322344322),
#  'IL-Springfield': (49868.0, 19.5, 90.8),
#  'IL-Stockton': (37500.0, 16.1, 94.1),
#  'IL-Villa Park': (70176.0, 9.8, 90.9),
#  'IL-Washington Park': (26136.0, 41.8, 71.7),
#  'IL-Zion': (46313.0, 19.2, 81.3),
#  'IN-Avon': (91393.0, 3.3, 94.2),
#  'IN-Beech Grove': (36487.0, 21.6, 85.7),
#  'IN-Brookville': (38333.0, 16.0, 85.4),
#  'IN-Elkhart': (35371.0, 26.7, 77.6),
#  'IN-English': (17438.0, 39.6, 67.1),
#  'IN-Evansville': (35785.0, 21.0, 87.5),
#  'IN-Fishers': (95487.0, 3.2, 97.4),
#  'IN-Fort Wayne': (43774.0, 19.0, 88.3),
#  'IN-French Lick': (28603.0, 33.7, 72.9),
#  'IN-Gary': (28020.0, 37.1, 83.9),
#  'IN-Goshen': (41117.0, 22.6, 76.0),
#  'IN-Greenwood': (54176.0, 13.7, 91.5),
#  'IN-Hanover': (40758.0, 24.8, 83.7),
#  'IN-Harmony': (41853.0, 6.8, 89.4),
#  'IN-Indianapolis': (47713.01078582434, 15.49985294117647, 86.31926470588236),
#  'IN-Knox': (33125.0, 20.9, 75.1),
#  'IN-Kokomo': (37623.0, 21.3, 86.3),
#  'IN-Lafayette': (40419.0, 19.8, 85.6),
#  'IN-Monon': (35542.0, 31.1, 74.5),
#  'IN-Muncie': (31044.0, 32.2, 86.4),
#  'IN-Portage': (53730.0, 16.3, 88.2),
#  'IN-Shelbyville': (43395.0, 16.9, 83.4),
#  'IN-Terre Haute': (31817.0, 27.4, 84.4),
#  'IN-Vincennes': (35455.0, 23.9, 85.4),
#  'KS-Assaria': (51250.0, 8.2, 95.9),
#  'KS-Colby': (44679.0, 11.1, 92.0),
#  'KS-Gardner': (67422.0, 3.8, 94.4),
#  'KS-Hays': (44838.94357366771, 14.762985074626867, 88.23044776119401),
#  'MO-Big Bear': (41747.616016427106, 20.105859375, 83.522265625),
#  'MO-Blue Springs': (63753.0, 10.5, 93.8),
#  'MO-Buffalo': (34898.0, 25.8, 79.3),
#  'MO-Cape Girardeau': (40107.0, 25.9, 88.7),
#  'MO-Columbia': (44907.0, 24.4, 93.8),
#  'MO-Florissant': (50767.0, 8.5, 91.7),
#  'MO-Franklin County': (41747.616016427106, 20.105859375, 83.522265625),
#  'MO-Harrisonville': (41196.0, 14.3, 90.8),
#  'MO-Independence': (43472.0, 17.9, 87.6),
#  'MO-Jackson': (41747.616016427106, 20.105859375, 83.522265625),
#  'MO-Jennings': (29393.0, 29.9, 79.5),
#  'MO-Kansas City': (45821.0, 19.0, 88.4),
#  'MO-Lakeshire': (43438.0, 13.0, 92.5),
#  'MO-Lampe': (41747.616016427106, 20.105859375, 83.522265625),
#  "MO-Lee's Summit": (78377.0, 6.5, 96.4),
#  'MO-Maysville': (28472.0, 14.4, 84.9),
#  'MO-McDowell': (41747.616016427106, 20.105859375, 83.522265625),
#  'MO-Neosho': (36266.0, 20.2, 80.6),
#  'MO-Nevada': (28683.0, 27.1, 85.6),
#  'MO-North St. Louis': (41747.616016427106, 20.105859375, 83.522265625),
#  'MO-Odessa': (52066.0, 11.7, 94.9),
#  'MO-Ozark': (45695.0, 12.6, 89.2),
#  'MO-Poplar Bluff': (29536.0, 27.7, 80.5),
#  'MO-Republic': (50972.0, 15.8, 93.2),
#  'MO-Sedalia': (31460.0, 23.9, 80.7),
#  'MO-Springfield': (33557.0, 25.7, 88.3),
#  'MO-St Louis': (41747.616016427106, 20.105859375, 83.522265625),
#  'MO-St. Joseph': (43298.0, 19.9, 86.4),
#  'MO-St. Louis': (35599.0, 27.1, 84.1),
#  'MO-Sugar Creek': (35738.0, 15.5, 88.2),
#  'MO-Sullivan': (30507.0, 19.0, 79.3),
#  'MS-Barton': (35002.09912536443, 26.88425414364641, 78.4707182320442),
#  'MS-Biloxi': (39011.0, 24.6, 85.1),
#  'MS-Brookhaven': (30487.0, 37.1, 84.8),
#  'MS-Columbus': (35002.09912536443, 26.88425414364641, 78.4707182320442),
#  'MS-Gautier': (44675.0, 15.2, 88.4),
#  'MS-Greenville': (29206.0, 36.8, 78.7),
#  'MS-Gulfport': (36474.0, 25.5, 84.5),
#  'MS-Hattiesburg': (26852.0, 37.8, 84.6),
#  'MS-Iuka': (31684.0, 20.9, 68.8),
#  'MS-Lucedale': (38900.0, 30.9, 77.5),
#  'MS-Petal': (53169.0, 11.8, 88.5),
#  'MS-Ruth': (35002.09912536443, 26.88425414364641, 78.4707182320442),
#  'MS-Smithville': (37583.0, 15.8, 77.6),
#  'MS-Southaven': (58227.0, 11.4, 88.4),
#  'MS-St. Martin': (44579.0, 17.2, 86.2),
#  'MS-Tupelo': (41487.0, 23.3, 87.2),
#  'MS-Walls': (38558.0, 18.7, 87.2),
#  'MS-Water Valley': (30218.0, 26.5, 77.3),
#  'MT-Billings': (51012.0, 12.8, 92.8),
#  'MT-Butte': (45119.98119122257, 16.513774104683197, 90.48842975206612),
#  'MT-Dillon': (38750.0, 22.0, 92.5),
#  'MT-Huntley': (45119.98119122257, 0.0, 100.0),
#  'MT-Livingston': (40619.0, 12.7, 94.7),
#  'MT-Malta': (30697.0, 14.3, 88.8),
#  'MT-Superior': (22069.0, 25.5, 89.2),
#  'MT-Three Forks': (51603.0, 8.6, 90.9),
#  'NC-Anson County': (43302.33758865248, 19.74728997289973, 83.24945799457996),
#  'NC-Archdale': (50420.0, 10.5, 81.4),
#  'NC-Ashe County': (43302.33758865248, 19.74728997289973, 83.24945799457996),
#  'NC-Asheville': (43334.0, 17.3, 92.3),
#  'NC-Brevard': (39659.0, 12.7, 89.9),
#  'NC-Canton': (34388.0, 16.9, 79.9),
#  'NC-Cary': (91579.0, 6.3, 95.3),
#  'NC-Charlotte': (53637.0, 16.8, 88.4),
#  'NC-Clinton': (31997.0, 29.2, 81.5),
#  'NC-Dallas': (34770.0, 16.4, 82.7),
#  'NC-Dublin': (30800.0, 28.0, 75.1),
#  'NC-Durham': (50420.0, 19.2, 87.1),
#  'NC-East Flat Rock': (26193.0, 28.7, 74.1),
#  'NC-Efland': (52736.0, 2.4, 99.1),
#  'NC-Fayetteville': (43630.0, 18.4, 91.2),
#  'NC-Franklin': (43302.33758865248, 19.74728997289973, 83.24945799457996),
#  'NC-Gaston County': (43302.33758865248, 19.74728997289973, 83.24945799457996),
#  'NC-Gastonia': (40432.0, 20.8, 83.2),
#  'NC-Granite Falls': (43409.0, 20.2, 77.6),
#  'NC-Greensboro': (41628.0, 19.3, 88.7),
#  'NC-Greenville': (34435.0, 32.5, 91.6),
#  'NC-Hickory': (43338.0, 17.5, 84.3),
#  'NC-Hudson': (44196.0, 14.1, 88.0),
#  'NC-Iredell County': (43302.33758865248,
#   19.74728997289973,
#   83.24945799457996),
#  'NC-Kinston': (28060.0, 33.1, 80.3),
#  'NC-Lawndale': (31750.0, 21.4, 82.8),
#  'NC-Leland': (61374.0, 14.2, 93.5),
#  'NC-Lenoir': (31063.0, 22.8, 77.0),
#  'NC-Lumberton': (31245.0, 34.8, 74.1),
#  'NC-Maiden': (48324.0, 18.1, 76.5),
#  'NC-Newton Grove': (32292.0, 15.8, 80.0),
#  'NC-Peachland': (35000.0, 31.6, 80.9),
#  'NC-Pinnacle': (43302.33758865248, 8.1, 76.5),
#  'NC-Pleasant Hill': (21544.0, 25.3, 61.6),
#  'NC-Raleigh': (55398.0, 16.0, 90.5),
#  'NC-Ronda': (30662.0, 23.0, 62.3),
#  'NC-Rowland': (21298.0, 36.2, 77.1),
#  'NC-Rutherfordton': (39274.0, 17.8, 87.1),
#  'NC-Salemburg': (36528.0, 16.8, 80.9),
#  'NC-Salisbury': (36701.0, 23.3, 82.4),
#  'NC-Shelby': (34300.0, 29.0, 85.1),
#  'NC-Spring Lake': (36964.0, 21.4, 91.5),
#  'NC-Statesville': (32728.0, 28.4, 80.1),
#  'NC-Stoneville': (38313.0, 10.6, 81.2),
#  'NC-Tarboro': (33349.0, 17.0, 75.0),
#  'NM-Albuquerque': (47030.0, 19.2, 89.0),
#  'NM-Artesia': (50701.0, 10.9, 81.8),
#  'NM-Carlsbad': (51097.0, 13.5, 85.6),
#  'NM-Carrizozo': (22841.0, 34.3, 83.9),
#  'NM-Crownpoint': (39250.0, 31.6, 82.5),
#  'NM-Deming': (25844.0, 33.1, 66.3),
#  'NM-Edgewood': (57386.0, 7.7, 97.2),
#  'NM-Eldorado': (70881.0, 8.3, 98.4),
#  'NM-Gallup': (46467.0, 25.5, 79.9),
#  'NM-Hanover': (40952.90536277602, 38.4, 100.0),
#  'NM-Hobbs': (56905.0, 16.5, 72.7),
#  'NM-Jal': (51667.0, 6.6, 72.6),
#  'NM-Laguna Pueblo': (40952.90536277602, 23.08078703703704, 80.98263888888889),
#  'NM-Las Cruces': (41330.0, 24.4, 85.5),
#  'NM-Los Lunas': (52166.0, 16.4, 87.7),
#  'NM-Lovington': (51450.0, 19.7, 64.5),
#  'NM-Pueblo of Laguna': (40952.90536277602,
#   23.08078703703704,
#   80.98263888888889),
#  'NM-Roswell': (39975.0, 22.1, 80.3),
#  'NM-Rowe': (46250.0, 27.4, 96.3),
#  'NM-Ruidoso': (40952.90536277602, 23.08078703703704, 80.98263888888889),
#  'NM-San Rafael': (69103.0, 2.3, 81.1),
#  'NM-Santa Fe': (50737.0, 17.6, 85.7),
#  'NM-Socorro': (33359.0, 30.2, 72.1),
#  'NM-Taos': (40952.90536277602, 23.08078703703704, 80.98263888888889),
#  'NM-Truth or Consequences': (26877.0, 25.9, 82.2),
#  'NV-Boulder City': (56405.0, 10.3, 93.3),
#  'NV-Carson City': (47668.0, 16.8, 86.8),
#  'NV-Gardnerville Ranchos': (52179.0, 15.7, 94.5),
#  'NV-Henderson': (63120.0, 9.8, 92.7),
#  'NV-Jean': (57322.970588235294, 12.466153846153846, 87.71538461538462),
#  'NV-Las Vegas': (50202.0, 17.5, 83.3),
#  'NV-North Las Vegas': (52511.0, 16.6, 78.2),
#  'NV-Pahrump': (41229.0, 18.9, 85.2),
#  'NV-Reno': (47012.0, 18.3, 85.7),
#  'NV-Silver Springs': (33780.0, 22.8, 81.4),
#  'NV-Sparks': (52795.0, 13.0, 85.5),
#  'NY-Beacon': (65305.0, 11.6, 89.3),
#  'NY-Berne': (69890.67151411463, 11.668231349538978, 90.61372384937239),
#  'NY-Bronx': (198839.0, 3.0, 98.7),
#  'NY-Brooklyn': (69890.67151411463, 11.668231349538978, 90.61372384937239),
#  ...}

# %%
df_total_copy = df_total.copy()
df_total_copy['Median Income'] = 0
df_total_copy
# Out:
#           id                name      date   manner_of_death       armed  \
# 0        3.0          Tim Elliot  02/01/15              shot         gun
# 1        4.0    Lewis Lee Lembke  02/01/15              shot         gun
# 2        5.0  John Paul Quintero  03/01/15  shot and Tasered     unarmed
# 3        8.0     Matthew Hoffman  04/01/15              shot  toy weapon
# 4        9.0   Michael Rodriguez  04/01/15              shot    nail gun
# ...      ...                 ...       ...               ...         ...
# 2530  2822.0    Rodney E. Jacobs  28/07/17              shot         gun
# 2531  2813.0               TK TK  28/07/17              shot     vehicle
# 2532  2818.0  Dennis W. Robinson  29/07/17              shot         gun
# 2533  2817.0       Isaiah Tucker  31/07/17              shot     vehicle
# 2534  2815.0        Dwayne Jeune  31/07/17              shot       knife
#
#             age gender race              city state  signs_of_mental_illness  \
# 0     53.000000      M    A        WA-Shelton    WA                     True
# 1     47.000000      M    W          OR-Aloha    OR                    False
# 2     23.000000      M    H        KS-Wichita    KS                    False
# 3     32.000000      M    W  CA-San Francisco    CA                     True
# 4     39.000000      M    H          CO-Evans    CO                    False
# ...         ...    ...  ...               ...   ...                      ...
# 2530  31.000000      M    B    MO-Kansas City    MO                    False
# 2531  31.153846      M    H    NM-Albuquerque    NM                    False
# 2532  48.000000      M    W          ID-Melba    ID                    False
# 2533  28.000000      M    B        WI-Oshkosh    WI                    False
# 2534  32.000000      M    B       NY-Brooklyn    NY                     True
#
#      threat_level         flee  body_camera  Median Income
# 0          attack  Not fleeing        False              0
# 1          attack  Not fleeing        False              0
# 2           other  Not fleeing        False              0
# 3          attack  Not fleeing        False              0
# 4          attack  Not fleeing        False              0
# ...           ...          ...          ...            ...
# 2530       attack  Not fleeing        False              0
# 2531       attack          Car        False              0
# 2532       attack          Car        False              0
# 2533       attack          Car         True              0
# 2534       attack  Not fleeing        False              0
#
# [2535 rows x 15 columns]

# %%
df_support
# Out:
#      Geographic area       City share_white share_black share_native_american  \
# 0                 AK  Anchorage        66.0         5.6                   7.9
# 1                 AK     Barrow        16.9         1.0                  61.2
# 2                 AK   Big Lake        86.1         0.2                   7.0
# 3                 AK  Fairbanks        66.1         9.0                  10.0
# 4                 AK    Houston        82.2         0.4                   6.7
# ...              ...        ...         ...         ...                   ...
# 1529              WY   Cheyenne        87.4         2.9                   1.0
# 1530              WY    Douglas        94.4         0.3                   0.8
# 1531              WY   Gillette        92.2         0.4                   1.2
# 1532              WY    Laramie        89.5         1.3                   0.7
# 1533              WY    Rawlins        84.7         1.1                   1.3
#
#      share_asian share_hispanic          city Median Income poverty_rate  \
# 0            8.1            7.6  AK-Anchorage       78326.0          8.2
# 1            9.1            3.1     AK-Barrow       76902.0         11.7
# 2            0.5            3.1   AK-Big Lake       70988.0          9.6
# 3            3.6            9.0  AK-Fairbanks       55229.0         13.1
# 4            0.6            3.3    AK-Houston       50438.0         14.8
# ...          ...            ...           ...           ...          ...
# 1529         1.2           14.5   WY-Cheyenne       58219.0         11.2
# 1530         0.2            7.6    WY-Douglas       60060.0          9.2
# 1531         0.7            9.5   WY-Gillette       74165.0          9.0
# 1532         3.2            9.2    WY-Laramie       39371.0         30.0
# 1533         1.0           24.3    WY-Rawlins       56838.0         15.7
#
#      percent_completed_hs    index
# 0                    93.0     14.0
# 1                    84.6     25.0
# 2                    90.4     32.0
# 3                    91.2     95.0
# 4                    90.2    135.0
# ...                   ...      ...
# 1529                 93.4  29312.0
# 1530                 91.2  29327.0
# 1531                 90.4  29350.0
# 1532                 96.7  29383.0
# 1533                 88.3  29428.0
#
# [1534 rows x 12 columns]
